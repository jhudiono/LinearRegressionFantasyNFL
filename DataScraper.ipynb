# %% [markdown]
# * Parse fantasy data from FFToday
# * Parse injury data
# * Parse Google trends data
# * Save to CSVs
#
# From previous game:
# * Position (WR, TE, RB)
# * Rush yards
# * Receive yards
# * Touchdowns
# * Fumbles
# * Fantasy points gained
# * Hype (google searches)
# * injury status
#
# From previous season:
# * ESPN rank avg
#
# Misc
# * Age
# * Division (AFC North, NFC East, etc)
# * Team
# * ADP (avg draft position)
# * NFL Combine scores (?)
# * Years of experience/# of games (?)
#
#
# Goal:
# * Rank,Name        ,Division ,Team,Position,Season,Week,Age,Rush,Receive,Touchdown,Fumble,Points,ADP ,Injury,Hype
# * 1   ,Alvin Kamara,NFC South,NO  ,RB      ,2017  ,12  ,22 ,100 ,88     ,2        ,1     ,25.1  ,1.06,0     ,98

# %%
import os
import pandas as pd
import re
import requests
import time

from __future__ import print_function
from bs4 import BeautifulSoup
from selenium import webdriver
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.firefox.options import Options

DELAY = 2  # seconds

#RB = 20
#WR = 30
#TE = 40

#fantasy_url = "http://games.espn.com/ffl/leaders"

'''
options = Options()
driver = webdriver.Firefox(firefox_options=options)
driver.get("fantasy_url")
'''
# Out:
# '\noptions = Options()\ndriver = webdriver.Firefox(firefox_options=options)\ndriver.get("fantasy_url")\n'

# %% [markdown]
# # FFToday
# * Generate URLs to scrape
# * Load pages
# * Parse DF from pages
# * Concat DF by position
# * Save CSV for each DF

# %%
# Info about FFToday's website
FFTODAY = {
    'base_url' : "http://fftoday.com/stats/playerstats.php?Season={}&GameWeek={}&PosID={}",
    'seasons' : range(2001, 2018),
    'weeks' : range(1, 18),
    'position_index' : [20,30,40],  # RB, WR, TE
    'columns' : {
        20: ['name','team','g','rush_att','rush_yd','rush_td','rec_target','rec_rec','rec_yd','rec_td','fp','fpg'],
        30: ['name','team','g','rec_target','rec_rec','rec_yd','rec_td','rush_att','rush_yd','rush_td','fp','fpg'],
        40: ['name','team','g','rec_target','rec_rec','rec_yd','rec_td','fp','fpg'],
    }
}

# %%
def fftoday_urls(seasons=[2017], weeks=[10,11,12], positions=[20,30,40]):
    '''Return a list of FFToday URL tuples: (season, week, position, url).'''
    arr = []
    for p in positions:
        for s in seasons:
            for w in weeks:
                arr.append((s, w, p, 
                            str.format(FFTODAY['base_url'], s, w, p)))
    return arr

def scrape(url=str.format(FFTODAY['base_url'], 2017, 17, 20)):
    '''Return the raw text and soup for the URL.'''
    print("Reading", url)
    response = requests.get(url)
    return BeautifulSoup(response.text,"lxml")

def parse_page_to_dataframe(soup):
    '''Return dataframe.'''
    players = {}
    for n, link in enumerate(soup.find_all(href=re.compile('/stats/players'))):
        name = link.text
        if name != "players":
            row = link.findParent().findParent()
            # RB: Name,Team,G,Rush Att,Rush Yd,Rush TD,Rec Target,Rec Rec,Rec Yd,Rec TD,FPts,FPts/G 
            players[n] = [td.text for td in row.find_all('td')]
            # separate name and rank
            players[n][0] = name
    return pd.DataFrame(players).T

def save_to_csv(dataframe, key=''):
    # save to CSV
    file = str.format("data/fftoday_{}_{}.csv", dataframe.season[1], 'pos'+str(key))
    print("Saving to file", file)
    dataframe.to_csv(file)

fftoday_urls()
# Out:
# [(2017,
#   10,
#   20,
#   'http://fftoday.com/stats/playerstats.php?Season=2017&GameWeek=10&PosID=20'),
#  (2017,
#   11,
#   20,
#   'http://fftoday.com/stats/playerstats.php?Season=2017&GameWeek=11&PosID=20'),
#  (2017,
#   12,
#   20,
#   'http://fftoday.com/stats/playerstats.php?Season=2017&GameWeek=12&PosID=20'),
#  (2017,
#   10,
#   30,
#   'http://fftoday.com/stats/playerstats.php?Season=2017&GameWeek=10&PosID=30'),
#  (2017,
#   11,
#   30,
#   'http://fftoday.com/stats/playerstats.php?Season=2017&GameWeek=11&PosID=30'),
#  (2017,
#   12,
#   30,
#   'http://fftoday.com/stats/playerstats.php?Season=2017&GameWeek=12&PosID=30'),
#  (2017,
#   10,
#   40,
#   'http://fftoday.com/stats/playerstats.php?Season=2017&GameWeek=10&PosID=40'),
#  (2017,
#   11,
#   40,
#   'http://fftoday.com/stats/playerstats.php?Season=2017&GameWeek=11&PosID=40'),
#  (2017,
#   12,
#   40,
#   'http://fftoday.com/stats/playerstats.php?Season=2017&GameWeek=12&PosID=40')]

# %%
text, soup = scrape('http://fftoday.com/stats/playerstats.php?Season=2017&GameWeek=12&PosID=40')
print(text)
# Out:
# <!DOCTYPE HTML PUBLIC '-//W3C//DTD HTML 4.0 Transitional//EN'>
# <html>
#
# <head>
# <title>Tight End Stats: 2017 Week 12 - FF Today</title>
# <META NAME='description' CONTENT='NFL and fantasy football stats from FF Today.'>
# <META NAME='keywords' CONTENT='stats, statistics, nfl, fantasy football, quarterbacks, running backs, wide receivers, tight ends, defensive linemen, linebackers, defensive backs'>
# <meta property='og:image' content=''>
#
# <LINK rel='STYLESHEET' type='text/css' href='/fftoday2.css'>
# <link rel='stylesheet' type='text/css' href='/css/slimbox2.css' media='screen' />
# <link rel='stylesheet' href='/themes/fft_default/style.css' type='text/css' media='print, projection, screen' />
# <script type='text/javascript' language='javascript' src='/rollOverColors.js'></script>
# <script type='text/javascript' src='/js/jquery.js'></script>
# <script type='text/javascript' src='/js/slimbox2.js'></script>
# <meta http-equiv='Content-Type' content='text/html; charset=UTF-8'>
#
# <script type='text/javascript' src='/js/jquery.tablesorter.js'></script>
# <script>
# $(document).ready(function()
#     {
#         $('#myTable').tablesorter();
#     }
# );
#
# // extend the default setting to always include the zebra widget.
#     $.tablesorter.defaults.widgets = ['zebra'];
# </script>
#
# <!-- Start DFP SETUP -->
# <script type="text/javascript"><!--
# //<![CDATA[
# (function() {
# var useSSL = 'https:' == document.location.protocol;
# var src = (useSSL ? 'https:' : 'http:') + '//www.googletagservices.com/tag/js/gpt.js';
# document.write('<scr' + 'ipt src="' + src + '"></scr' + 'ipt>');
# })();
# //]]>
# //--></script>
# <script type='text/javascript' src='http://img.bnqt.com/lib/js/sdpdfphelper.js'></script>
# <script type="text/javascript">
# googletag.pubads().enableSyncRendering();
# googletag.pubads().setTargeting("title", sdpTargeting.title)
#                   .setTargeting('targetPaths', sdpTargeting.targetPaths)
#                   .setTargeting('fullPath', sdpTargeting.fullPath)
#                   .setTargeting('queryStr', sdpTargeting.queryStr)
#                   .setTargeting('domainName', sdpTargeting.domainName);
# </script>
# <script type="text/javascript">
# window._UrlSegment = window._UrlSegment || '';
# window._SitePage = window._SitePage || '';
# _UrlSegment = window.location.toString().replace(/http:\/\//, '').split('/');
# _SitePage = _UrlSegment[1].match(/^$|^(index.php)+$/i) ? 'main' : 'general';
# </script>
# <!-- End DFP SETUP -->
#
# <!-- Begin comScore Tag -->
# <script>
#   var _comscore = _comscore || [];
#   _comscore.push({ c1: "2", c2: "6035210" });
#   (function() {
#     var s = document.createElement("script"), el = document.getElementsByTagName("script")[0]; s.async = true;
#     s.src = (document.location.protocol == "https:" ? "https://sb" : "http://b") + ".scorecardresearch.com/beacon.js";
#     el.parentNode.insertBefore(s, el);
#   })();
# </script>
# <noscript>
#   <img src="http://b.scorecardresearch.com/p?c1=2&c2=6035210&cv=2.0&cj=1" />
# </noscript>
# <!-- End comScore Tag -->
#
# <!-- Begin Google Analytics -->
# <script type="text/javascript">
#
#   var _gaq = _gaq || [];
#   _gaq.push(['_setAccount', 'UA-37923979-1']);
#   _gaq.push(['_setDomainName', 'fftoday.com']);
#   _gaq.push(['_setAllowLinker', true]);
#   _gaq.push(['_trackPageview']);
#
#   (function() {
#     var ga = document.createElement('script'); ga.type = 'text/javascript'; ga.async = true;
#     ga.src = ('https:' == document.location.protocol ? 'https://ssl' : 'http://www') + '.google-analytics.com/ga.js';
#     var s = document.getElementsByTagName('script')[0]; s.parentNode.insertBefore(ga, s);
#   })();
#
# </script>
# <!-- End Google Analytics -->
#
# <!-- Social Share Buttons -->
# <script>!function(d,s,id){var js,fjs=d.getElementsByTagName(s)[0];if(!d.getElementById(id)){js=d.createElement(s);js.id=id;js.src='https://platform.twitter.com/widgets.js';fjs.parentNode.insertBefore(js,fjs);}}(document,'script','twitter-wjs');</script>
# <div id='fb-root'></div>
# <script>(function(d, s, id) {
#   var js, fjs = d.getElementsByTagName(s)[0];
#   if (d.getElementById(id)) return;
#   js = d.createElement(s); js.id = id;
#   js.src = '//connect.facebook.net/en_US/sdk.js#xfbml=1&version=v2.10';
#   fjs.parentNode.insertBefore(js, fjs);
# }(document, 'script', 'facebook-jssdk'));</script>
#
# <!-- End Social Share Buttons -->
#
# </head>
#
# <body marginwidth='0' marginheight='0' leftmargin='0' topmargin='0' text='#333333' link='005FA9' vlink='#666666' alink='#336699'>
# <center>
#
# <table width='990' border='0' align='center' cellpadding='0' cellspacing='0' bgcolor='#FFFFFF'>
#     <tr>
#       <td valign='top' width='10' bgcolor='#FFFFFF' rowspan='2'>&nbsp;</td>
#       <td width='220' rowspan='2' valign='top'><img src='/common/spacer_whi.gif' width='2' height='5'><br>
#         <a href='/index.html'><img src='/creative/08_179_fftoday.gif' alt='Fantasy Football Today - fantasy football rankings, cheatsheets, and information' width='179' height='106' border='0'></a><br>
#         <span class='logotease'>A Fantasy Football Community!</span><br>
#         <!-- Todays Date -->
# 		<img src='/common/spacer_whi.gif' width='1' height='5'><br>
# 		<span class='date'>
#         <!-- Todays Date -->
# 	  <script language="JavaScript"><!--
#        var DayOfWeek = new Array('Sunday','Monday','Tuesday','Wednesday','Thursday','Friday','Saturday');
#        var MonthName = new Array('January','February','March','April','May','June','July','August','September',
#                           'October','November','December');
#        var theDate = new Date();
#        document.write('<NOBR>' +
#                DayOfWeek[theDate.getDay()] + ', ' +
# 			   MonthName[theDate.getMonth()] + ' ' +
#                theDate.getDate() + ', 2018' +
#
#               '</font></NOBR>');
#         //--></script><br><img src="/common/spacer_whi.gif" width="2" height="3"><br></span></td>
#       <td align='center' valign='top'><img src='/common/spacer_whi.gif' width='2' height='5'><br>
#       <!-- SMG_FFToday/728x90_1a/sports/fantasy/NFL.general -->
# <!-- --> <div id="usmg_ad_NFL.general_fantasy_sports_728x90_1a">
# <script type='text/javascript'>
# googletag.defineSlot('/7103/SMG_FFToday/728x90_1a/sports/fantasy/NFL.general', [728,90], 'usmg_ad_NFL.general_fantasy_sports_728x90_1a').addService(googletag.pubads());
# googletag.enableServices();
# googletag.display('usmg_ad_NFL.general_fantasy_sports_728x90_1a');
# </script>
# </div>
# <!-- SMG_FFToday/728x90_1a/sports/fantasy/NFL.general end -->
#
#  </td>
#     </tr>
#     <tr>
#       <td rowspan='2' align='right' valign='bottom' class='date'> <a href='http://www.fftoday.com/members/?r=myfftoday'>Log In</a>&nbsp; | <a href='http://www.fftoday.com/signup_fftoday.php'>Sign Up</a>&nbsp; | &nbsp;<a href='http://www.fftoday.com/contact/index.htm'>Contact</a>&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;<br>
#         <img src='/common/spacer_whi.gif' width='2' height='5'><br> <table width='100%' border='0' cellpadding='0' cellspacing='0'>
#           <form action='http://sub.ezinedirector.net/index.cfm' method='post'>
# 								<input name='fuseaction' type='hidden' value='s' />
# 								<input name='EzineID' type='hidden' value='964693455' />
# 				<tr valign='center'>
#             <td> <table width='275' height='20' border='0' align='right' cellpadding='0' cellspacing='0'>
#                 <tr>
#                   <td nowrap class='navhdrnewsletter'>Free Newsletter!</td>
#                   <td nowrap><img src='/common/blank2.gif' width='5' height='20' align='top'></td>
#                   <td><input maxlength='255' name='email' type='text' class='input' value=' enter email address' /></td>
#                   <td><img src='/common/blank2.gif' width='5' height='20' border='0'></td>
#                   <td valign='top'> <input name='image' type='image' value='submit' src='/common/btn_go_white.gif' alt='Submit' hspace=0 vspace=0 border=0></td>
#                   <td><img src='/common/blank2.gif' width='20' height='20' border='0'></td>
#                 </tr>
#               </table></td>
#           </tr>
#         </form>
#       </table> </td>
#     </tr>
#   </table>
# <!-- End Logo/Leaderboard Table -->
#
#   <div class='nav'>
# <ul>
# 	<li id='mArticles'><a href='/articles/index.htm'>articles</a></li>
# 	<li id='mRankings_Projections'><a href='/rankings/index.html'>rankings / projections</a></li>
# 	<li id='mNews'><a href='/news/index.php'>news</a></li>
# 	<li id='mContests'><a href='/contests/index.php'>contests</a></li>
# 	<li id='mPlayers'><a href='/stats/players'>players</a></li>
# 	<li id='mStats'><a href='/stats/index.htm'>stats</a></li>
# 	<li id='mTools'><a href='/tools/index.htm'>tools</a></li>
# 	<li id='mNFL_Resources'><a href='/nfl/index.htm'>nfl resources</a></li>
# 	<li id='mForums'><a href='http://www.fftodayforums.com/'>forums</a></li>
# 	<li id='mMy_FFToday'><a href='/myfftoday/index.php'>my fftoday</a></li>
# </ul>
# <div class='clear'></div>
# </div>
# <!-- SMG_FFToday/launchpad/sports/fantasy/NFL.general -->
#
# <!-- SMG_FFToday/launchpad/sports/fantasy/NFL.general end -->
#
#   <table bgcolor='white' cellspacing='0' cellpadding='0' border='0' width='990' align='center'>
#     <tr>
#       <td width='20' bgcolor='#ffffff' valign='top' rowspan='2'><img src='/common/spacer_whi.gif' width='20' height='2'><br>
#       </td>
#       <td align='right' valign='top' width='770'><img src='/common/spacer_whi.gif' width='5' height='2'><br>
#  		</td>
#       <td width='20' bgcolor='#ffffff' rowspan='2' valign='top'><img src='/common/spacer_whi.gif' width='20' height='2'><br>
#       </td>
#       <td width='180' align='center' valign='top' class='adcolumn'><img src='/common/spacer_whi.gif' width='5' height='2'><br>
#       </td>
#
#     </tr>
#     <tr>
#       <td valign='top' class='bodycontent'><table width='100%' border='0' cellspacing='0' cellpadding='0'>
#           <tr>
# 		  	<td width='100%'>&nbsp;<span class="breadcrumb"><a href="../stats/index.htm" class="breadcrumb">Stats</a> &gt; Player Stats</span></td>
# 			<td align='right' nowrap> &nbsp;</td>
# 		  </tr>
# 		</table><img src='/common/spacer_whi.gif' width='5' height='10'><table width='100%' border='0' cellspacing='1' cellpadding='3'>
#           <tr>
#
#             <td class='pageheader'>Tight End Stats: 2017</td>
#             <td class='date' align='right' valign='bottom' nowrap>&nbsp;</td>
#           </tr>
#           <tr>
#             <td colspan='2'><img src='/common/hdr_nav_tile_black3.gif' width='765' height='1'></td>
#           </tr>
#           <tr>
# 		    <td width='100%' class='update' colspan='2'> Week 12<br></td>
#
# 		  </tr>
#         </table>
# 		<img src='/common/spacer_whi.gif' alt='' border='0' width='1' height='4'><br>
#         <!-- Begin Content Table------------------------------------------------->
# <table class='bodycontent'><tr><td>
# <strong>Want Custom Fantasy Scoring?</strong><br>
# You are not logged in. You must be logged in and create a league profile to apply
# custom fantasy scoring to the stats, projections and rankings pages.
# <a href='../members/?r=playerstats'>Login</a> or <a href='../signup.php?r=playerstats'>Register</a>
# </td></tr></table>
# <br><table class='navstats'>
# 	<tr>
# 		<td><strong>Position: </strong></td>
# 		<td><a href='?Season=2017&GameWeek=12&PosID=10&LeagueID='>QB</a> |
# 		<a href='?Season=2017&GameWeek=12&PosID=20&LeagueID='>RB</a> |
# 		<a href='?Season=2017&GameWeek=12&PosID=30&LeagueID='>WR</a> |
# 		<a href='?Season=2017&GameWeek=12&PosID=40&LeagueID='>TE</a> |
# 		<a href='?Season=2017&GameWeek=12&PosID=80&LeagueID='>K</a> |
# 		<a href='?Season=2017&GameWeek=12&PosID=99&LeagueID='>DEF</a> |
# 		<a href='?Season=2017&GameWeek=12&PosID=50&LeagueID='>DL</a> |
# 		<a href='?Season=2017&GameWeek=12&PosID=60&LeagueID='>LB</a> |
# 		<a href='?Season=2017&GameWeek=12&PosID=70&LeagueID='>DB</a></td>
# 	</tr>
# 	<tr>
# 		<td><strong>Season: </strong></td>
# 		<td><a href='?Season=2017&GameWeek=12&PosID=40&LeagueID='>2017</a> |
# 		<a href='?Season=2016&GameWeek=12&PosID=40&LeagueID='>2016</a> |
# 		<a href='?Season=2015&GameWeek=12&PosID=40&LeagueID='>2015</a> |
# 		<a href='?Season=2014&GameWeek=12&PosID=40&LeagueID='>2014</a> |
# 		<a href='?Season=2013&GameWeek=12&PosID=40&LeagueID='>2013</a> |
# 		<a href='?Season=2012&GameWeek=12&PosID=40&LeagueID='>2012</a> |
# 		<a href='?Season=2011&GameWeek=12&PosID=40&LeagueID='>2011</a> |
# 		<a href='?Season=2010&GameWeek=12&PosID=40&LeagueID='>2010</a> |
# 		<a href='?Season=2009&GameWeek=12&PosID=40&LeagueID='>2009</a> |
# 		<a href='?Season=2008&GameWeek=12&PosID=40&LeagueID='>2008</a> |
# 		<a href='?Season=2007&GameWeek=12&PosID=40&LeagueID='>2007</a> |
# 		<a href='?Season=2006&GameWeek=12&PosID=40&LeagueID='>2006</a> |
# 		<a href='?Season=2005&GameWeek=12&PosID=40&LeagueID='>2005</a> |
# 		<a href='?Season=2004&GameWeek=12&PosID=40&LeagueID='>2004</a> |
# 		<a href='?Season=2003&GameWeek=12&PosID=40&LeagueID='>2003</a> |
# 		<a href='?Season=2002&GameWeek=12&PosID=40&LeagueID='>2002</a> |
# 		<a href='?Season=2001&GameWeek=12&PosID=40&LeagueID='>2001</a>
# 		</td>
# 	</tr>
# 	<tr>
# 		<td><strong>Week: </strong></td>
# 		<td><a href='?Season=2017&GameWeek=1&PosID=40&LeagueID='>1</a> |
# 		<a href='?Season=2017&GameWeek=2&PosID=40&LeagueID='>2</a> |
# 		<a href='?Season=2017&GameWeek=3&PosID=40&LeagueID='>3</a> |
# 		<a href='?Season=2017&GameWeek=4&PosID=40&LeagueID='>4</a> |
# 		<a href='?Season=2017&GameWeek=5&PosID=40&LeagueID='>5</a> |
# 		<a href='?Season=2017&GameWeek=6&PosID=40&LeagueID='>6</a> |
# 		<a href='?Season=2017&GameWeek=7&PosID=40&LeagueID='>7</a> |
# 		<a href='?Season=2017&GameWeek=8&PosID=40&LeagueID='>8</a> |
# 		<a href='?Season=2017&GameWeek=9&PosID=40&LeagueID='>9</a> |
# 		<a href='?Season=2017&GameWeek=10&PosID=40&LeagueID='>10</a> |
# 		<a href='?Season=2017&GameWeek=11&PosID=40&LeagueID='>11</a> |
# 		<a href='?Season=2017&GameWeek=12&PosID=40&LeagueID='>12</a> |
# 		<a href='?Season=2017&GameWeek=13&PosID=40&LeagueID='>13</a> |
# 		<a href='?Season=2017&GameWeek=14&PosID=40&LeagueID='>14</a> |
# 		<a href='?Season=2017&GameWeek=15&PosID=40&LeagueID='>15</a> |
# 		<a href='?Season=2017&GameWeek=16&PosID=40&LeagueID='>16</a> |
# 		<a href='?Season=2017&GameWeek=17&PosID=40&LeagueID='>17</a></td>
# 	</tr>
# 	<tr>
# 		<td><strong>Playoffs: </strong></td>
# 		<td><a href='?Season=2017&GameWeek=21&PosID=40&LeagueID='>Wild-Card</a> |
# 		<a href='?Season=2017&GameWeek=22&PosID=40&LeagueID='>Divisional Playoffs</a> |
# 		<a href='?Season=2017&GameWeek=23&PosID=40&LeagueID='>Conference Championships</a> |
# 		<a href='?Season=2017&GameWeek=24&PosID=40&LeagueID='>Super Bowl</a></td>
# 	</tr>
# 	<tr>
# 		<td><strong>Options: </strong></td>
# 		<td><a href='?Season=2017&GameWeek=Last3&PosID=40&LeagueID='>Last 3 Weeks</a> |
# 		<a href='?Season=2017&GameWeek=Last5&PosID=40&LeagueID='>Last 5 Weeks</a> |
# 		<a href='?Season=2017&GameWeek=Season&PosID=40&LeagueID='>Season</a> |
# 		<a href='?Season=2017&GameWeek=Playoffs&PosID=40&LeagueID='>Playoffs</a></td>
# 	</tr>
# </table>
# <br>
#  <script language='JavaScript' type='text/javascript'>
#  <!--
#  function reviewscoring_pop() { window.open('../myfftoday/reviewscoring.php?LeagueID=&PosID=40','ReviewScoring','width=250,height=400,resizable=yes,scrollbars=yes'); }
#  //-->
#  </script>
# <table width='100%' border=0 cellpadding=1 cellspacing=1>
# <form action='' method='get' name='PlayerStats'>
# <input type='hidden' name='Season' value='2017'>
# <input type='hidden' name='GameWeek' value='12'>
# <input type='hidden' name='PosID' value='40'>
# 	<tr>
# 		<td align='left' valign='top' nowrap><span class='smallbody'>FF Today Standard Scoring: <a href='javascript:reviewscoring_pop();'>Review Scoring</a></span></td>
# 		<td align='right' valign='top'>
# 		<SELECT NAME='LeagueID' onchange='this.form.submit();' class='articledrop'>
# 		<OPTION VALUE=''>&nbsp;&nbsp; My FF Today </OPTION>
# 		<OPTION VALUE=''></OPTION>
#
# 		<OPTION VALUE=''>&gt; Pre-Set Scoring </OPTION>
# 		<OPTION VALUE='1' >&nbsp;&nbsp; FF Today Standard</OPTION>
# 		<OPTION VALUE='107644' >&nbsp;&nbsp; FF Today PPR</OPTION>
# 		<OPTION VALUE='193033' >&nbsp;&nbsp; FF Today Half-Point PPR</OPTION>
# 		<OPTION VALUE='26943' >&nbsp;&nbsp; CBS Sports</OPTION>
# 		<OPTION VALUE='26955' >&nbsp;&nbsp; ESPN</OPTION>
# 		<OPTION VALUE='17' >&nbsp;&nbsp; Yahoo!</OPTION>
# 		<OPTION VALUE='143908' >&nbsp;&nbsp; NFL.com</OPTION>
# 		<OPTION VALUE='107437' >&nbsp;&nbsp; FFPC</OPTION>
# 		<OPTION VALUE='5' >&nbsp;&nbsp; NFFC</OPTION></SELECT></td>
# </tr>
# </form>
# </table><table width='100%' border=0 cellpadding=0 cellspacing=0>
# <tr bgcolor='#eeeeee'>
# <td>
# <TABLE WIDTH='100%' CELLPADDING='2' CELLSPACING='1' BORDER='0'>
# 	<TR class='tablehdr'>
#    		<TD COLSPAN='3' ALIGN='left' VALIGN='middle' NOWRAP >&nbsp; </TD>
# 		<TD COLSPAN="4" ALIGN="center" NOWRAP>Receiving</TD>
# 		<TD bgcolor='#666666' COLSPAN='2' ALIGN='center' NOWRAP>Fantasy</TD>
# 	</TR>
# 	<TR class='tableclmhdr'>
# 		<TD ALIGN='center' VALIGN='middle' NOWRAP><B>Player</B><br>
# 		<span class='tableclmhdrsort'>Sort First: <A HREF='?Season=2017&GameWeek=12&PosID=40&LeagueID=&order_by=FName&sort_order=ASC'>
#         <IMG SRC='../images/asc.gif' WIDTH='11' HEIGHT='14' BORDER='0' align='absbottom'></A>
# 		<A HREF='?Season=2017&GameWeek=12&PosID=40&LeagueID=&order_by=FName&sort_order=DESC'>
#         <IMG SRC='../images/desc.gif' WIDTH='11' HEIGHT='14' BORDER='0' align='absbottom'></A>&nbsp;&nbsp;
# 		Last: <A HREF='?Season=2017&GameWeek=12&PosID=40&LeagueID=&order_by=LName&sort_order=ASC'>
# 		<IMG SRC='../images/asc.gif' WIDTH='11' HEIGHT='14' BORDER='0' align='absbottom'></A>
# 		<A HREF='?Season=2017&GameWeek=12&PosID=40&LeagueID=&order_by=LName&sort_order=DESC'>
# 		<IMG SRC='../images/desc.gif' WIDTH='11' HEIGHT='14' BORDER='0' align='absbottom'></A></span></TD>
#
# 		<TD ALIGN='center' NOWRAP ><B>Team</B><BR>
# 		<A HREF='?Season=2017&GameWeek=12&PosID=40&LeagueID=&order_by=TeamAbb&sort_order=ASC'>
# 		<IMG SRC='../images/asc.gif' WIDTH='11' HEIGHT='14' BORDER='0'></A>
# 		<A HREF='?Season=2017&GameWeek=12&PosID=40&LeagueID=&order_by=TeamAbb&sort_order=DESC'>
# 		<IMG SRC='../images/desc.gif' WIDTH='11' HEIGHT='14' BORDER='0'></A></TD>
#
# 		<TD ALIGN='center' NOWRAP><B>G</B><BR>
# 		<A HREF='?Season=2017&GameWeek=12&PosID=40&LeagueID=&order_by=Play&sort_order=ASC'>
# 		<IMG SRC='../images/asc.gif' WIDTH='11' HEIGHT='14' BORDER='0'></A>
# 		<A HREF='?Season=2017&GameWeek=12&PosID=40&LeagueID=&order_by=Play&sort_order=DESC'>
# 		<IMG SRC='../images/desc.gif' WIDTH='11' HEIGHT='14' BORDER='0'></A></TD>
#
# 		<!--
# 		<TD ALIGN='center' NOWRAP><B>GS</B><BR>
# 		<A HREF='?Season=2017&GameWeek=12&PosID=40&LeagueID=&order_by=Start&sort_order=ASC'>
# 		<IMG SRC='../images/asc.gif' WIDTH='11' HEIGHT='14' BORDER='0'></A>
# 		<A HREF='?Season=2017&GameWeek=12&PosID=40&LeagueID=&order_by=Start&sort_order=DESC'>
# 		<IMG SRC='../images/desc.gif' WIDTH='11' HEIGHT='14' BORDER='0'></A></TD>
# 		-->
#
# 		<TD ALIGN="center" NOWRAP BGCOLOR="#e0e0e0"><B>Target</B><BR>
# 				<A HREF='?Season=2017&GameWeek=12&PosID=40&LeagueID=&order_by=Target&sort_order=ASC'><IMG SRC="../images/asc.gif" WIDTH="11" HEIGHT="14" BORDER="0"></A>
# 				<A HREF='?Season=2017&GameWeek=12&PosID=40&LeagueID=&order_by=Target&sort_order=DESC'><IMG SRC="../images/desc.gif" WIDTH="11" HEIGHT="14" BORDER="0"></A></TD>
# 				<TD ALIGN="center" NOWRAP BGCOLOR="#e0e0e0"><B>Rec</B><BR>
# 				<A HREF='?Season=2017&GameWeek=12&PosID=40&LeagueID=&order_by=Rec&sort_order=ASC'><IMG SRC="../images/asc.gif" WIDTH="11" HEIGHT="14" BORDER="0"></A>
# 				<A HREF='?Season=2017&GameWeek=12&PosID=40&LeagueID=&order_by=Rec&sort_order=DESC'><IMG SRC="../images/desc.gif" WIDTH="11" HEIGHT="14" BORDER="0"></A></TD>
# 				<TD ALIGN="center" NOWRAP BGCOLOR="#e0e0e0"><B>Yard</B><BR>
# 				<A HREF='?Season=2017&GameWeek=12&PosID=40&LeagueID=&order_by=ReYd&sort_order=ASC'><IMG SRC="../images/asc.gif" WIDTH="11" HEIGHT="14" BORDER="0"></A>
# 				<A HREF='?Season=2017&GameWeek=12&PosID=40&LeagueID=&order_by=ReYd&sort_order=DESC'><IMG SRC="../images/desc.gif" WIDTH="11" HEIGHT="14" BORDER="0"></A></TD>
# 				<TD ALIGN="center" NOWRAP BGCOLOR="#e0e0e0"><B>TD</B><BR>
# 				<A HREF='?Season=2017&GameWeek=12&PosID=40&LeagueID=&order_by=ReTD&sort_order=ASC'><IMG SRC="../images/asc.gif" WIDTH="11" HEIGHT="14" BORDER="0"></A>
# 				<A HREF='?Season=2017&GameWeek=12&PosID=40&LeagueID=&order_by=ReTD&sort_order=DESC'><IMG SRC="../images/desc.gif" WIDTH="11" HEIGHT="14" BORDER="0"></A></TD>
#
# 		<TD ALIGN='center' NOWRAP><B>FPts</B><BR>
# 		<A HREF='?Season=2017&GameWeek=12&PosID=40&LeagueID=&order_by=FFPts&sort_order=ASC'>
# 		<IMG SRC='../images/asc.gif' WIDTH='11' HEIGHT='14' BORDER='0'></A>
# 		<A HREF='?Season=2017&GameWeek=12&PosID=40&LeagueID=&order_by=FFPts&sort_order=DESC'>
# 		<IMG SRC='../images/desc.gif' WIDTH='11' HEIGHT='14' BORDER='0'></A></TD>
#
# 		<TD ALIGN='center' NOWRAP><B>FPts/G</B><BR>
# 		<A HREF='?Season=2017&GameWeek=12&PosID=40&LeagueID=&order_by=FFPtsPerG&sort_order=ASC'>
# 		<IMG SRC='../images/asc.gif' WIDTH='11' HEIGHT='14' BORDER='0'></A>
# 		<A HREF='?Season=2017&GameWeek=12&PosID=40&LeagueID=&order_by=FFPtsPerG&sort_order=DESC'>
# 		<IMG SRC='../images/desc.gif' WIDTH='11' HEIGHT='14' BORDER='0'></A></TD>
# 	</TR>
# 	<TR>
# <TD CLASS="sort1" ALIGN="LEFT" BGCOLOR="#ffffff">&nbsp;1. <A HREF="/stats/players/11452/Rob_Gronkowski?LeagueID=">Rob Gronkowski</A></TD>
# <TD CLASS="sort1" ALIGN="center" BGCOLOR="#ffffff">NE</TD>
# <TD CLASS="sort1" ALIGN="center" BGCOLOR="#ffffff">1</TD>
# <TD CLASS="sort1" ALIGN="center" BGCOLOR="#ffffff">8</TD>
# <TD CLASS="sort1" ALIGN="center" BGCOLOR="#ffffff">5</TD>
# <TD CLASS="sort1" ALIGN="center" BGCOLOR="#ffffff">82</TD>
# <TD CLASS="sort1" ALIGN="center" BGCOLOR="#ffffff">2</TD>
# <TD CLASS="sort1" ALIGN="center" BGCOLOR="#e0e0e0">20.2</TD>
# <TD CLASS="sort1" ALIGN="center" BGCOLOR="#ffffff">20.2</TD>
# </TR>
# <TR>
# <TD CLASS="sort1" ALIGN="LEFT" BGCOLOR="#f7f7f7">&nbsp;2. <A HREF="/stats/players/11897/Kyle_Rudolph?LeagueID=">Kyle Rudolph</A></TD>
# <TD CLASS="sort1" ALIGN="center" BGCOLOR="#f7f7f7">MIN</TD>
# <TD CLASS="sort1" ALIGN="center" BGCOLOR="#f7f7f7">1</TD>
# <TD CLASS="sort1" ALIGN="center" BGCOLOR="#f7f7f7">4</TD>
# <TD CLASS="sort1" ALIGN="center" BGCOLOR="#f7f7f7">4</TD>
# <TD CLASS="sort1" ALIGN="center" BGCOLOR="#f7f7f7">63</TD>
# <TD CLASS="sort1" ALIGN="center" BGCOLOR="#f7f7f7">2</TD>
# <TD CLASS="sort1" ALIGN="center" BGCOLOR="#e0e0e0">18.3</TD>
# <TD CLASS="sort1" ALIGN="center" BGCOLOR="#f7f7f7">18.3</TD>
# </TR>
# <TR>
# <TD CLASS="sort1" ALIGN="LEFT" BGCOLOR="#ffffff">&nbsp;3. <A HREF="/stats/players/13104/Zach_Ertz?LeagueID=">Zach Ertz</A></TD>
# <TD CLASS="sort1" ALIGN="center" BGCOLOR="#ffffff">PHI</TD>
# <TD CLASS="sort1" ALIGN="center" BGCOLOR="#ffffff">1</TD>
# <TD CLASS="sort1" ALIGN="center" BGCOLOR="#ffffff">12</TD>
# <TD CLASS="sort1" ALIGN="center" BGCOLOR="#ffffff">10</TD>
# <TD CLASS="sort1" ALIGN="center" BGCOLOR="#ffffff">103</TD>
# <TD CLASS="sort1" ALIGN="center" BGCOLOR="#ffffff">1</TD>
# <TD CLASS="sort1" ALIGN="center" BGCOLOR="#e0e0e0">16.3</TD>
# <TD CLASS="sort1" ALIGN="center" BGCOLOR="#ffffff">16.3</TD>
# </TR>
# <TR>
# <TD CLASS="sort1" ALIGN="LEFT" BGCOLOR="#f7f7f7">&nbsp;4. <A HREF="/stats/players/15603/Hunter_Henry?LeagueID=">Hunter Henry</A></TD>
# <TD CLASS="sort1" ALIGN="center" BGCOLOR="#f7f7f7">LAC</TD>
# <TD CLASS="sort1" ALIGN="center" BGCOLOR="#f7f7f7">1</TD>
# <TD CLASS="sort1" ALIGN="center" BGCOLOR="#f7f7f7">5</TD>
# <TD CLASS="sort1" ALIGN="center" BGCOLOR="#f7f7f7">5</TD>
# <TD CLASS="sort1" ALIGN="center" BGCOLOR="#f7f7f7">76</TD>
# <TD CLASS="sort1" ALIGN="center" BGCOLOR="#f7f7f7">1</TD>
# <TD CLASS="sort1" ALIGN="center" BGCOLOR="#e0e0e0">13.6</TD>
# <TD CLASS="sort1" ALIGN="center" BGCOLOR="#f7f7f7">13.6</TD>
# </TR>
# <TR>
# <TD CLASS="sort1" ALIGN="LEFT" BGCOLOR="#ffffff">&nbsp;5. <A HREF="/stats/players/14974/Ricky_Seals-Jones?LeagueID=">Ricky Seals-Jones</A></TD>
# <TD CLASS="sort1" ALIGN="center" BGCOLOR="#ffffff">ARI</TD>
# <TD CLASS="sort1" ALIGN="center" BGCOLOR="#ffffff">1</TD>
# <TD CLASS="sort1" ALIGN="center" BGCOLOR="#ffffff">6</TD>
# <TD CLASS="sort1" ALIGN="center" BGCOLOR="#ffffff">4</TD>
# <TD CLASS="sort1" ALIGN="center" BGCOLOR="#ffffff">72</TD>
# <TD CLASS="sort1" ALIGN="center" BGCOLOR="#ffffff">1</TD>
# <TD CLASS="sort1" ALIGN="center" BGCOLOR="#e0e0e0">13.2</TD>
# <TD CLASS="sort1" ALIGN="center" BGCOLOR="#ffffff">13.2</TD>
# </TR>
# <TR>
# <TD CLASS="sort1" ALIGN="LEFT" BGCOLOR="#f7f7f7">&nbsp;6. <A HREF="/stats/players/2663/Delanie_Walker?LeagueID=">Delanie Walker</A></TD>
# <TD CLASS="sort1" ALIGN="center" BGCOLOR="#f7f7f7">TEN</TD>
# <TD CLASS="sort1" ALIGN="center" BGCOLOR="#f7f7f7">1</TD>
# <TD CLASS="sort1" ALIGN="center" BGCOLOR="#f7f7f7">5</TD>
# <TD CLASS="sort1" ALIGN="center" BGCOLOR="#f7f7f7">4</TD>
# <TD CLASS="sort1" ALIGN="center" BGCOLOR="#f7f7f7">63</TD>
# <TD CLASS="sort1" ALIGN="center" BGCOLOR="#f7f7f7">1</TD>
# <TD CLASS="sort1" ALIGN="center" BGCOLOR="#e0e0e0">12.3</TD>
# <TD CLASS="sort1" ALIGN="center" BGCOLOR="#f7f7f7">12.3</TD>
# </TR>
# <TR>
# <TD CLASS="sort1" ALIGN="LEFT" BGCOLOR="#ffffff">&nbsp;7. <A HREF="/stats/players/13094/Jack_Doyle?LeagueID=">Jack Doyle</A></TD>
# <TD CLASS="sort1" ALIGN="center" BGCOLOR="#ffffff">IND</TD>
# <TD CLASS="sort1" ALIGN="center" BGCOLOR="#ffffff">1</TD>
# <TD CLASS="sort1" ALIGN="center" BGCOLOR="#ffffff">8</TD>
# <TD CLASS="sort1" ALIGN="center" BGCOLOR="#ffffff">7</TD>
# <TD CLASS="sort1" ALIGN="center" BGCOLOR="#ffffff">94</TD>
# <TD CLASS="sort1" ALIGN="center" BGCOLOR="#ffffff">0</TD>
# <TD CLASS="sort1" ALIGN="center" BGCOLOR="#e0e0e0">9.4</TD>
# <TD CLASS="sort1" ALIGN="center" BGCOLOR="#ffffff">9.4</TD>
# </TR>
# <TR>
# <TD CLASS="sort1" ALIGN="LEFT" BGCOLOR="#f7f7f7">&nbsp;8. <A HREF="/stats/players/11505/Jimmy_Graham?LeagueID=">Jimmy Graham</A></TD>
# <TD CLASS="sort1" ALIGN="center" BGCOLOR="#f7f7f7">SEA</TD>
# <TD CLASS="sort1" ALIGN="center" BGCOLOR="#f7f7f7">1</TD>
# <TD CLASS="sort1" ALIGN="center" BGCOLOR="#f7f7f7">6</TD>
# <TD CLASS="sort1" ALIGN="center" BGCOLOR="#f7f7f7">3</TD>
# <TD CLASS="sort1" ALIGN="center" BGCOLOR="#f7f7f7">34</TD>
# <TD CLASS="sort1" ALIGN="center" BGCOLOR="#f7f7f7">1</TD>
# <TD CLASS="sort1" ALIGN="center" BGCOLOR="#e0e0e0">9.4</TD>
# <TD CLASS="sort1" ALIGN="center" BGCOLOR="#f7f7f7">9.4</TD>
# </TR>
# <TR>
# <TD CLASS="sort1" ALIGN="LEFT" BGCOLOR="#ffffff">&nbsp;9. <A HREF="/stats/players/15730/Nick_Vannett?LeagueID=">Nick Vannett</A></TD>
# <TD CLASS="sort1" ALIGN="center" BGCOLOR="#ffffff">SEA</TD>
# <TD CLASS="sort1" ALIGN="center" BGCOLOR="#ffffff">1</TD>
# <TD CLASS="sort1" ALIGN="center" BGCOLOR="#ffffff">4</TD>
# <TD CLASS="sort1" ALIGN="center" BGCOLOR="#ffffff">2</TD>
# <TD CLASS="sort1" ALIGN="center" BGCOLOR="#ffffff">29</TD>
# <TD CLASS="sort1" ALIGN="center" BGCOLOR="#ffffff">1</TD>
# <TD CLASS="sort1" ALIGN="center" BGCOLOR="#e0e0e0">8.9</TD>
# <TD CLASS="sort1" ALIGN="center" BGCOLOR="#ffffff">8.9</TD>
# </TR>
# <TR>
# <TD CLASS="sort1" ALIGN="LEFT" BGCOLOR="#f7f7f7">&nbsp;10. <A HREF="/stats/players/15233/Tyler_Kroft?LeagueID=">Tyler Kroft</A></TD>
# <TD CLASS="sort1" ALIGN="center" BGCOLOR="#f7f7f7">CIN</TD>
# <TD CLASS="sort1" ALIGN="center" BGCOLOR="#f7f7f7">1</TD>
# <TD CLASS="sort1" ALIGN="center" BGCOLOR="#f7f7f7">4</TD>
# <TD CLASS="sort1" ALIGN="center" BGCOLOR="#f7f7f7">3</TD>
# <TD CLASS="sort1" ALIGN="center" BGCOLOR="#f7f7f7">14</TD>
# <TD CLASS="sort1" ALIGN="center" BGCOLOR="#f7f7f7">1</TD>
# <TD CLASS="sort1" ALIGN="center" BGCOLOR="#e0e0e0">7.4</TD>
# <TD CLASS="sort1" ALIGN="center" BGCOLOR="#f7f7f7">7.4</TD>
# </TR>
# <TR>
# <TD CLASS="sort1" ALIGN="LEFT" BGCOLOR="#ffffff">&nbsp;11. <A HREF="/stats/players/14775/Xavier_Grimble?LeagueID=">Xavier Grimble</A></TD>
# <TD CLASS="sort1" ALIGN="center" BGCOLOR="#ffffff">PIT</TD>
# <TD CLASS="sort1" ALIGN="center" BGCOLOR="#ffffff">1</TD>
# <TD CLASS="sort1" ALIGN="center" BGCOLOR="#ffffff">1</TD>
# <TD CLASS="sort1" ALIGN="center" BGCOLOR="#ffffff">1</TD>
# <TD CLASS="sort1" ALIGN="center" BGCOLOR="#ffffff">1</TD>
# <TD CLASS="sort1" ALIGN="center" BGCOLOR="#ffffff">1</TD>
# <TD CLASS="sort1" ALIGN="center" BGCOLOR="#e0e0e0">6.1</TD>
# <TD CLASS="sort1" ALIGN="center" BGCOLOR="#ffffff">6.1</TD>
# </TR>
# <TR>
# <TD CLASS="sort1" ALIGN="LEFT" BGCOLOR="#f7f7f7">&nbsp;12. <A HREF="/stats/players/12028/Charles_Clay?LeagueID=">Charles Clay</A></TD>
# <TD CLASS="sort1" ALIGN="center" BGCOLOR="#f7f7f7">BUF</TD>
# <TD CLASS="sort1" ALIGN="center" BGCOLOR="#f7f7f7">1</TD>
# <TD CLASS="sort1" ALIGN="center" BGCOLOR="#f7f7f7">4</TD>
# <TD CLASS="sort1" ALIGN="center" BGCOLOR="#f7f7f7">4</TD>
# <TD CLASS="sort1" ALIGN="center" BGCOLOR="#f7f7f7">60</TD>
# <TD CLASS="sort1" ALIGN="center" BGCOLOR="#f7f7f7">0</TD>
# <TD CLASS="sort1" ALIGN="center" BGCOLOR="#e0e0e0">6.0</TD>
# <TD CLASS="sort1" ALIGN="center" BGCOLOR="#f7f7f7">6.0</TD>
# </TR>
# <TR>
# <TD CLASS="sort1" ALIGN="LEFT" BGCOLOR="#ffffff">&nbsp;13. <A HREF="/stats/players/15904/O.J._Howard?LeagueID=">O.J. Howard</A></TD>
# <TD CLASS="sort1" ALIGN="center" BGCOLOR="#ffffff">TB</TD>
# <TD CLASS="sort1" ALIGN="center" BGCOLOR="#ffffff">1</TD>
# <TD CLASS="sort1" ALIGN="center" BGCOLOR="#ffffff">4</TD>
# <TD CLASS="sort1" ALIGN="center" BGCOLOR="#ffffff">3</TD>
# <TD CLASS="sort1" ALIGN="center" BGCOLOR="#ffffff">52</TD>
# <TD CLASS="sort1" ALIGN="center" BGCOLOR="#ffffff">0</TD>
# <TD CLASS="sort1" ALIGN="center" BGCOLOR="#e0e0e0">5.2</TD>
# <TD CLASS="sort1" ALIGN="center" BGCOLOR="#ffffff">5.2</TD>
# </TR>
# <TR>
# <TD CLASS="sort1" ALIGN="LEFT" BGCOLOR="#f7f7f7">&nbsp;14. <A HREF="/stats/players/11983/Julius_Thomas?LeagueID=">Julius Thomas</A></TD>
# <TD CLASS="sort1" ALIGN="center" BGCOLOR="#f7f7f7">MIA</TD>
# <TD CLASS="sort1" ALIGN="center" BGCOLOR="#f7f7f7">1</TD>
# <TD CLASS="sort1" ALIGN="center" BGCOLOR="#f7f7f7">6</TD>
# <TD CLASS="sort1" ALIGN="center" BGCOLOR="#f7f7f7">5</TD>
# <TD CLASS="sort1" ALIGN="center" BGCOLOR="#f7f7f7">52</TD>
# <TD CLASS="sort1" ALIGN="center" BGCOLOR="#f7f7f7">0</TD>
# <TD CLASS="sort1" ALIGN="center" BGCOLOR="#e0e0e0">5.2</TD>
# <TD CLASS="sort1" ALIGN="center" BGCOLOR="#f7f7f7">5.2</TD>
# </TR>
# <TR>
# <TD CLASS="sort1" ALIGN="LEFT" BGCOLOR="#ffffff">&nbsp;15. <A HREF="/stats/players/15605/Tyler_Higbee?LeagueID=">Tyler Higbee</A></TD>
# <TD CLASS="sort1" ALIGN="center" BGCOLOR="#ffffff">LAR</TD>
# <TD CLASS="sort1" ALIGN="center" BGCOLOR="#ffffff">1</TD>
# <TD CLASS="sort1" ALIGN="center" BGCOLOR="#ffffff">3</TD>
# <TD CLASS="sort1" ALIGN="center" BGCOLOR="#ffffff">3</TD>
# <TD CLASS="sort1" ALIGN="center" BGCOLOR="#ffffff">48</TD>
# <TD CLASS="sort1" ALIGN="center" BGCOLOR="#ffffff">0</TD>
# <TD CLASS="sort1" ALIGN="center" BGCOLOR="#e0e0e0">4.8</TD>
# <TD CLASS="sort1" ALIGN="center" BGCOLOR="#ffffff">4.8</TD>
# </TR>
# <TR>
# <TD CLASS="sort1" ALIGN="LEFT" BGCOLOR="#f7f7f7">&nbsp;16. <A HREF="/stats/players/15971/David_Njoku?LeagueID=">David Njoku</A></TD>
# <TD CLASS="sort1" ALIGN="center" BGCOLOR="#f7f7f7">CLE</TD>
# <TD CLASS="sort1" ALIGN="center" BGCOLOR="#f7f7f7">1</TD>
# <TD CLASS="sort1" ALIGN="center" BGCOLOR="#f7f7f7">4</TD>
# <TD CLASS="sort1" ALIGN="center" BGCOLOR="#f7f7f7">4</TD>
# <TD CLASS="sort1" ALIGN="center" BGCOLOR="#f7f7f7">47</TD>
# <TD CLASS="sort1" ALIGN="center" BGCOLOR="#f7f7f7">0</TD>
# <TD CLASS="sort1" ALIGN="center" BGCOLOR="#e0e0e0">4.7</TD>
# <TD CLASS="sort1" ALIGN="center" BGCOLOR="#f7f7f7">4.7</TD>
# </TR>
# <TR>
# <TD CLASS="sort1" ALIGN="LEFT" BGCOLOR="#ffffff">&nbsp;17. <A HREF="/stats/players/2272/Jason_Witten?LeagueID=">Jason Witten</A></TD>
# <TD CLASS="sort1" ALIGN="center" BGCOLOR="#ffffff">DAL</TD>
# <TD CLASS="sort1" ALIGN="center" BGCOLOR="#ffffff">1</TD>
# <TD CLASS="sort1" ALIGN="center" BGCOLOR="#ffffff">7</TD>
# <TD CLASS="sort1" ALIGN="center" BGCOLOR="#ffffff">7</TD>
# <TD CLASS="sort1" ALIGN="center" BGCOLOR="#ffffff">44</TD>
# <TD CLASS="sort1" ALIGN="center" BGCOLOR="#ffffff">0</TD>
# <TD CLASS="sort1" ALIGN="center" BGCOLOR="#e0e0e0">4.4</TD>
# <TD CLASS="sort1" ALIGN="center" BGCOLOR="#ffffff">4.4</TD>
# </TR>
# <TR>
# <TD CLASS="sort1" ALIGN="LEFT" BGCOLOR="#f7f7f7">&nbsp;18. <A HREF="/stats/players/13217/Travis_Kelce?LeagueID=">Travis Kelce</A></TD>
# <TD CLASS="sort1" ALIGN="center" BGCOLOR="#f7f7f7">KC</TD>
# <TD CLASS="sort1" ALIGN="center" BGCOLOR="#f7f7f7">1</TD>
# <TD CLASS="sort1" ALIGN="center" BGCOLOR="#f7f7f7">4</TD>
# <TD CLASS="sort1" ALIGN="center" BGCOLOR="#f7f7f7">3</TD>
# <TD CLASS="sort1" ALIGN="center" BGCOLOR="#f7f7f7">39</TD>
# <TD CLASS="sort1" ALIGN="center" BGCOLOR="#f7f7f7">0</TD>
# <TD CLASS="sort1" ALIGN="center" BGCOLOR="#e0e0e0">3.9</TD>
# <TD CLASS="sort1" ALIGN="center" BGCOLOR="#f7f7f7">3.9</TD>
# </TR>
# <TR>
# <TD CLASS="sort1" ALIGN="LEFT" BGCOLOR="#ffffff">&nbsp;19. <A HREF="/stats/players/15610/Austin_Hooper?LeagueID=">Austin Hooper</A></TD>
# <TD CLASS="sort1" ALIGN="center" BGCOLOR="#ffffff">ATL</TD>
# <TD CLASS="sort1" ALIGN="center" BGCOLOR="#ffffff">1</TD>
# <TD CLASS="sort1" ALIGN="center" BGCOLOR="#ffffff">5</TD>
# <TD CLASS="sort1" ALIGN="center" BGCOLOR="#ffffff">3</TD>
# <TD CLASS="sort1" ALIGN="center" BGCOLOR="#ffffff">38</TD>
# <TD CLASS="sort1" ALIGN="center" BGCOLOR="#ffffff">0</TD>
# <TD CLASS="sort1" ALIGN="center" BGCOLOR="#e0e0e0">3.8</TD>
# <TD CLASS="sort1" ALIGN="center" BGCOLOR="#ffffff">3.8</TD>
# </TR>
# <TR>
# <TD CLASS="sort1" ALIGN="LEFT" BGCOLOR="#f7f7f7">&nbsp;20. <A HREF="/stats/players/14177/C.J._Fiedorowicz?LeagueID=">C.J. Fiedorowicz</A></TD>
# <TD CLASS="sort1" ALIGN="center" BGCOLOR="#f7f7f7">HOU</TD>
# <TD CLASS="sort1" ALIGN="center" BGCOLOR="#f7f7f7">1</TD>
# <TD CLASS="sort1" ALIGN="center" BGCOLOR="#f7f7f7">8</TD>
# <TD CLASS="sort1" ALIGN="center" BGCOLOR="#f7f7f7">4</TD>
# <TD CLASS="sort1" ALIGN="center" BGCOLOR="#f7f7f7">37</TD>
# <TD CLASS="sort1" ALIGN="center" BGCOLOR="#f7f7f7">0</TD>
# <TD CLASS="sort1" ALIGN="center" BGCOLOR="#e0e0e0">3.7</TD>
# <TD CLASS="sort1" ALIGN="center" BGCOLOR="#f7f7f7">3.7</TD>
# </TR>
# <TR>
# <TD CLASS="sort1" ALIGN="LEFT" BGCOLOR="#ffffff">&nbsp;21. <A HREF="/stats/players/14165/Eric_Ebron?LeagueID=">Eric Ebron</A></TD>
# <TD CLASS="sort1" ALIGN="center" BGCOLOR="#ffffff">DET</TD>
# <TD CLASS="sort1" ALIGN="center" BGCOLOR="#ffffff">1</TD>
# <TD CLASS="sort1" ALIGN="center" BGCOLOR="#ffffff">4</TD>
# <TD CLASS="sort1" ALIGN="center" BGCOLOR="#ffffff">4</TD>
# <TD CLASS="sort1" ALIGN="center" BGCOLOR="#ffffff">34</TD>
# <TD CLASS="sort1" ALIGN="center" BGCOLOR="#ffffff">0</TD>
# <TD CLASS="sort1" ALIGN="center" BGCOLOR="#e0e0e0">3.4</TD>
# <TD CLASS="sort1" ALIGN="center" BGCOLOR="#ffffff">3.4</TD>
# </TR>
# <TR>
# <TD CLASS="sort1" ALIGN="LEFT" BGCOLOR="#f7f7f7">&nbsp;22. <A HREF="/stats/players/15071/Austin_Traylor?LeagueID=">Austin Traylor</A></TD>
# <TD CLASS="sort1" ALIGN="center" BGCOLOR="#f7f7f7">DEN</TD>
# <TD CLASS="sort1" ALIGN="center" BGCOLOR="#f7f7f7">1</TD>
# <TD CLASS="sort1" ALIGN="center" BGCOLOR="#f7f7f7">4</TD>
# <TD CLASS="sort1" ALIGN="center" BGCOLOR="#f7f7f7">1</TD>
# <TD CLASS="sort1" ALIGN="center" BGCOLOR="#f7f7f7">34</TD>
# <TD CLASS="sort1" ALIGN="center" BGCOLOR="#f7f7f7">0</TD>
# <TD CLASS="sort1" ALIGN="center" BGCOLOR="#e0e0e0">3.4</TD>
# <TD CLASS="sort1" ALIGN="center" BGCOLOR="#f7f7f7">3.4</TD>
# </TR>
# <TR>
# <TD CLASS="sort1" ALIGN="LEFT" BGCOLOR="#ffffff">&nbsp;23. <A HREF="/stats/players/15562/Seth_Devalve?LeagueID=">Seth Devalve</A></TD>
# <TD CLASS="sort1" ALIGN="center" BGCOLOR="#ffffff">CLE</TD>
# <TD CLASS="sort1" ALIGN="center" BGCOLOR="#ffffff">1</TD>
# <TD CLASS="sort1" ALIGN="center" BGCOLOR="#ffffff">2</TD>
# <TD CLASS="sort1" ALIGN="center" BGCOLOR="#ffffff">2</TD>
# <TD CLASS="sort1" ALIGN="center" BGCOLOR="#ffffff">33</TD>
# <TD CLASS="sort1" ALIGN="center" BGCOLOR="#ffffff">0</TD>
# <TD CLASS="sort1" ALIGN="center" BGCOLOR="#e0e0e0">3.3</TD>
# <TD CLASS="sort1" ALIGN="center" BGCOLOR="#ffffff">3.3</TD>
# </TR>
# <TR>
# <TD CLASS="sort1" ALIGN="LEFT" BGCOLOR="#f7f7f7">&nbsp;24. <A HREF="/stats/players/13149/Demetrius_Harris?LeagueID=">Demetrius Harris</A></TD>
# <TD CLASS="sort1" ALIGN="center" BGCOLOR="#f7f7f7">KC</TD>
# <TD CLASS="sort1" ALIGN="center" BGCOLOR="#f7f7f7">1</TD>
# <TD CLASS="sort1" ALIGN="center" BGCOLOR="#f7f7f7">2</TD>
# <TD CLASS="sort1" ALIGN="center" BGCOLOR="#f7f7f7">2</TD>
# <TD CLASS="sort1" ALIGN="center" BGCOLOR="#f7f7f7">33</TD>
# <TD CLASS="sort1" ALIGN="center" BGCOLOR="#f7f7f7">0</TD>
# <TD CLASS="sort1" ALIGN="center" BGCOLOR="#e0e0e0">3.3</TD>
# <TD CLASS="sort1" ALIGN="center" BGCOLOR="#f7f7f7">3.3</TD>
# </TR>
# <TR>
# <TD CLASS="sort1" ALIGN="LEFT" BGCOLOR="#ffffff">&nbsp;25. <A HREF="/stats/players/15218/Jesse_James?LeagueID=">Jesse James</A></TD>
# <TD CLASS="sort1" ALIGN="center" BGCOLOR="#ffffff">PIT</TD>
# <TD CLASS="sort1" ALIGN="center" BGCOLOR="#ffffff">1</TD>
# <TD CLASS="sort1" ALIGN="center" BGCOLOR="#ffffff">4</TD>
# <TD CLASS="sort1" ALIGN="center" BGCOLOR="#ffffff">3</TD>
# <TD CLASS="sort1" ALIGN="center" BGCOLOR="#ffffff">32</TD>
# <TD CLASS="sort1" ALIGN="center" BGCOLOR="#ffffff">0</TD>
# <TD CLASS="sort1" ALIGN="center" BGCOLOR="#e0e0e0">3.2</TD>
# <TD CLASS="sort1" ALIGN="center" BGCOLOR="#ffffff">3.2</TD>
# </TR>
# <TR>
# <TD CLASS="sort1" ALIGN="LEFT" BGCOLOR="#f7f7f7">&nbsp;26. <A HREF="/stats/players/3085/Ben_Watson?LeagueID=">Ben Watson</A></TD>
# <TD CLASS="sort1" ALIGN="center" BGCOLOR="#f7f7f7">BAL</TD>
# <TD CLASS="sort1" ALIGN="center" BGCOLOR="#f7f7f7">1</TD>
# <TD CLASS="sort1" ALIGN="center" BGCOLOR="#f7f7f7">3</TD>
# <TD CLASS="sort1" ALIGN="center" BGCOLOR="#f7f7f7">3</TD>
# <TD CLASS="sort1" ALIGN="center" BGCOLOR="#f7f7f7">29</TD>
# <TD CLASS="sort1" ALIGN="center" BGCOLOR="#f7f7f7">0</TD>
# <TD CLASS="sort1" ALIGN="center" BGCOLOR="#e0e0e0">2.9</TD>
# <TD CLASS="sort1" ALIGN="center" BGCOLOR="#f7f7f7">2.9</TD>
# </TR>
# <TR>
# <TD CLASS="sort1" ALIGN="LEFT" BGCOLOR="#ffffff">&nbsp;27. <A HREF="/stats/players/14311/Austin_Seferian-Jenkins?LeagueID=">Austin Seferian-Jenkins</A></TD>
# <TD CLASS="sort1" ALIGN="center" BGCOLOR="#ffffff">NYJ</TD>
# <TD CLASS="sort1" ALIGN="center" BGCOLOR="#ffffff">1</TD>
# <TD CLASS="sort1" ALIGN="center" BGCOLOR="#ffffff">7</TD>
# <TD CLASS="sort1" ALIGN="center" BGCOLOR="#ffffff">2</TD>
# <TD CLASS="sort1" ALIGN="center" BGCOLOR="#ffffff">27</TD>
# <TD CLASS="sort1" ALIGN="center" BGCOLOR="#ffffff">0</TD>
# <TD CLASS="sort1" ALIGN="center" BGCOLOR="#e0e0e0">2.7</TD>
# <TD CLASS="sort1" ALIGN="center" BGCOLOR="#ffffff">2.7</TD>
# </TR>
# <TR>
# <TD CLASS="sort1" ALIGN="LEFT" BGCOLOR="#f7f7f7">&nbsp;28. <A HREF="/stats/players/14302/Richard_Rodgers?LeagueID=">Richard Rodgers</A></TD>
# <TD CLASS="sort1" ALIGN="center" BGCOLOR="#f7f7f7">GB</TD>
# <TD CLASS="sort1" ALIGN="center" BGCOLOR="#f7f7f7">1</TD>
# <TD CLASS="sort1" ALIGN="center" BGCOLOR="#f7f7f7">3</TD>
# <TD CLASS="sort1" ALIGN="center" BGCOLOR="#f7f7f7">1</TD>
# <TD CLASS="sort1" ALIGN="center" BGCOLOR="#f7f7f7">25</TD>
# <TD CLASS="sort1" ALIGN="center" BGCOLOR="#f7f7f7">0</TD>
# <TD CLASS="sort1" ALIGN="center" BGCOLOR="#e0e0e0">2.5</TD>
# <TD CLASS="sort1" ALIGN="center" BGCOLOR="#f7f7f7">2.5</TD>
# </TR>
# <TR>
# <TD CLASS="sort1" ALIGN="LEFT" BGCOLOR="#ffffff">&nbsp;29. <A HREF="/stats/players/14273/Troy_Niklas?LeagueID=">Troy Niklas</A></TD>
# <TD CLASS="sort1" ALIGN="center" BGCOLOR="#ffffff">ARI</TD>
# <TD CLASS="sort1" ALIGN="center" BGCOLOR="#ffffff">1</TD>
# <TD CLASS="sort1" ALIGN="center" BGCOLOR="#ffffff">2</TD>
# <TD CLASS="sort1" ALIGN="center" BGCOLOR="#ffffff">2</TD>
# <TD CLASS="sort1" ALIGN="center" BGCOLOR="#ffffff">22</TD>
# <TD CLASS="sort1" ALIGN="center" BGCOLOR="#ffffff">0</TD>
# <TD CLASS="sort1" ALIGN="center" BGCOLOR="#e0e0e0">2.2</TD>
# <TD CLASS="sort1" ALIGN="center" BGCOLOR="#ffffff">2.2</TD>
# </TR>
# <TR>
# <TD CLASS="sort1" ALIGN="LEFT" BGCOLOR="#f7f7f7">&nbsp;30. <A HREF="/stats/players/14695/Daniel_Brown?LeagueID=">Daniel Brown</A></TD>
# <TD CLASS="sort1" ALIGN="center" BGCOLOR="#f7f7f7">CHI</TD>
# <TD CLASS="sort1" ALIGN="center" BGCOLOR="#f7f7f7">1</TD>
# <TD CLASS="sort1" ALIGN="center" BGCOLOR="#f7f7f7">3</TD>
# <TD CLASS="sort1" ALIGN="center" BGCOLOR="#f7f7f7">2</TD>
# <TD CLASS="sort1" ALIGN="center" BGCOLOR="#f7f7f7">20</TD>
# <TD CLASS="sort1" ALIGN="center" BGCOLOR="#f7f7f7">0</TD>
# <TD CLASS="sort1" ALIGN="center" BGCOLOR="#e0e0e0">2.0</TD>
# <TD CLASS="sort1" ALIGN="center" BGCOLOR="#f7f7f7">2.0</TD>
# </TR>
# <TR>
# <TD CLASS="sort1" ALIGN="LEFT" BGCOLOR="#ffffff">&nbsp;31. <A HREF="/stats/players/15862/Evan_Engram?LeagueID=">Evan Engram</A></TD>
# <TD CLASS="sort1" ALIGN="center" BGCOLOR="#ffffff">NYG</TD>
# <TD CLASS="sort1" ALIGN="center" BGCOLOR="#ffffff">1</TD>
# <TD CLASS="sort1" ALIGN="center" BGCOLOR="#ffffff">7</TD>
# <TD CLASS="sort1" ALIGN="center" BGCOLOR="#ffffff">3</TD>
# <TD CLASS="sort1" ALIGN="center" BGCOLOR="#ffffff">18</TD>
# <TD CLASS="sort1" ALIGN="center" BGCOLOR="#ffffff">0</TD>
# <TD CLASS="sort1" ALIGN="center" BGCOLOR="#e0e0e0">1.8</TD>
# <TD CLASS="sort1" ALIGN="center" BGCOLOR="#ffffff">1.8</TD>
# </TR>
# <TR>
# <TD CLASS="sort1" ALIGN="LEFT" BGCOLOR="#f7f7f7">&nbsp;32. <A HREF="/stats/players/15268/Nick_O'Leary?LeagueID=">Nick O'Leary</A></TD>
# <TD CLASS="sort1" ALIGN="center" BGCOLOR="#f7f7f7">BUF</TD>
# <TD CLASS="sort1" ALIGN="center" BGCOLOR="#f7f7f7">1</TD>
# <TD CLASS="sort1" ALIGN="center" BGCOLOR="#f7f7f7">2</TD>
# <TD CLASS="sort1" ALIGN="center" BGCOLOR="#f7f7f7">2</TD>
# <TD CLASS="sort1" ALIGN="center" BGCOLOR="#f7f7f7">18</TD>
# <TD CLASS="sort1" ALIGN="center" BGCOLOR="#f7f7f7">0</TD>
# <TD CLASS="sort1" ALIGN="center" BGCOLOR="#e0e0e0">1.8</TD>
# <TD CLASS="sort1" ALIGN="center" BGCOLOR="#f7f7f7">1.8</TD>
# </TR>
# <TR>
# <TD CLASS="sort1" ALIGN="LEFT" BGCOLOR="#ffffff">&nbsp;33. <A HREF="/stats/players/12058/Virgil_Green?LeagueID=">Virgil Green</A></TD>
# <TD CLASS="sort1" ALIGN="center" BGCOLOR="#ffffff">DEN</TD>
# <TD CLASS="sort1" ALIGN="center" BGCOLOR="#ffffff">1</TD>
# <TD CLASS="sort1" ALIGN="center" BGCOLOR="#ffffff">3</TD>
# <TD CLASS="sort1" ALIGN="center" BGCOLOR="#ffffff">1</TD>
# <TD CLASS="sort1" ALIGN="center" BGCOLOR="#ffffff">16</TD>
# <TD CLASS="sort1" ALIGN="center" BGCOLOR="#ffffff">0</TD>
# <TD CLASS="sort1" ALIGN="center" BGCOLOR="#e0e0e0">1.6</TD>
# <TD CLASS="sort1" ALIGN="center" BGCOLOR="#ffffff">1.6</TD>
# </TR>
# <TR>
# <TD CLASS="sort1" ALIGN="LEFT" BGCOLOR="#f7f7f7">&nbsp;34. <A HREF="/stats/players/12009/Niles_Paul?LeagueID=">Niles Paul</A></TD>
# <TD CLASS="sort1" ALIGN="center" BGCOLOR="#f7f7f7">WAS</TD>
# <TD CLASS="sort1" ALIGN="center" BGCOLOR="#f7f7f7">1</TD>
# <TD CLASS="sort1" ALIGN="center" BGCOLOR="#f7f7f7">5</TD>
# <TD CLASS="sort1" ALIGN="center" BGCOLOR="#f7f7f7">3</TD>
# <TD CLASS="sort1" ALIGN="center" BGCOLOR="#f7f7f7">16</TD>
# <TD CLASS="sort1" ALIGN="center" BGCOLOR="#f7f7f7">0</TD>
# <TD CLASS="sort1" ALIGN="center" BGCOLOR="#e0e0e0">1.6</TD>
# <TD CLASS="sort1" ALIGN="center" BGCOLOR="#f7f7f7">1.6</TD>
# </TR>
# <TR>
# <TD CLASS="sort1" ALIGN="LEFT" BGCOLOR="#ffffff">&nbsp;35. <A HREF="/stats/players/11480/Ed_Dickson?LeagueID=">Ed Dickson</A></TD>
# <TD CLASS="sort1" ALIGN="center" BGCOLOR="#ffffff">CAR</TD>
# <TD CLASS="sort1" ALIGN="center" BGCOLOR="#ffffff">1</TD>
# <TD CLASS="sort1" ALIGN="center" BGCOLOR="#ffffff">3</TD>
# <TD CLASS="sort1" ALIGN="center" BGCOLOR="#ffffff">1</TD>
# <TD CLASS="sort1" ALIGN="center" BGCOLOR="#ffffff">15</TD>
# <TD CLASS="sort1" ALIGN="center" BGCOLOR="#ffffff">0</TD>
# <TD CLASS="sort1" ALIGN="center" BGCOLOR="#e0e0e0">1.5</TD>
# <TD CLASS="sort1" ALIGN="center" BGCOLOR="#ffffff">1.5</TD>
# </TR>
# <TR>
# <TD CLASS="sort1" ALIGN="LEFT" BGCOLOR="#f7f7f7">&nbsp;36. <A HREF="/stats/players/15929/George_Kittle?LeagueID=">George Kittle</A></TD>
# <TD CLASS="sort1" ALIGN="center" BGCOLOR="#f7f7f7">SF</TD>
# <TD CLASS="sort1" ALIGN="center" BGCOLOR="#f7f7f7">1</TD>
# <TD CLASS="sort1" ALIGN="center" BGCOLOR="#f7f7f7">2</TD>
# <TD CLASS="sort1" ALIGN="center" BGCOLOR="#f7f7f7">1</TD>
# <TD CLASS="sort1" ALIGN="center" BGCOLOR="#f7f7f7">14</TD>
# <TD CLASS="sort1" ALIGN="center" BGCOLOR="#f7f7f7">0</TD>
# <TD CLASS="sort1" ALIGN="center" BGCOLOR="#e0e0e0">1.4</TD>
# <TD CLASS="sort1" ALIGN="center" BGCOLOR="#f7f7f7">1.4</TD>
# </TR>
# <TR>
# <TD CLASS="sort1" ALIGN="LEFT" BGCOLOR="#ffffff">&nbsp;37. <A HREF="/stats/players/11431/Jermaine_Gresham?LeagueID=">Jermaine Gresham</A></TD>
# <TD CLASS="sort1" ALIGN="center" BGCOLOR="#ffffff">ARI</TD>
# <TD CLASS="sort1" ALIGN="center" BGCOLOR="#ffffff">1</TD>
# <TD CLASS="sort1" ALIGN="center" BGCOLOR="#ffffff">3</TD>
# <TD CLASS="sort1" ALIGN="center" BGCOLOR="#ffffff">2</TD>
# <TD CLASS="sort1" ALIGN="center" BGCOLOR="#ffffff">13</TD>
# <TD CLASS="sort1" ALIGN="center" BGCOLOR="#ffffff">0</TD>
# <TD CLASS="sort1" ALIGN="center" BGCOLOR="#e0e0e0">1.3</TD>
# <TD CLASS="sort1" ALIGN="center" BGCOLOR="#ffffff">1.3</TD>
# </TR>
# <TR>
# <TD CLASS="sort1" ALIGN="LEFT" BGCOLOR="#f7f7f7">&nbsp;38. <A HREF="/stats/players/12013/Lee_Smith?LeagueID=">Lee Smith</A></TD>
# <TD CLASS="sort1" ALIGN="center" BGCOLOR="#f7f7f7">OAK</TD>
# <TD CLASS="sort1" ALIGN="center" BGCOLOR="#f7f7f7">1</TD>
# <TD CLASS="sort1" ALIGN="center" BGCOLOR="#f7f7f7">1</TD>
# <TD CLASS="sort1" ALIGN="center" BGCOLOR="#f7f7f7">1</TD>
# <TD CLASS="sort1" ALIGN="center" BGCOLOR="#f7f7f7">12</TD>
# <TD CLASS="sort1" ALIGN="center" BGCOLOR="#f7f7f7">0</TD>
# <TD CLASS="sort1" ALIGN="center" BGCOLOR="#e0e0e0">1.2</TD>
# <TD CLASS="sort1" ALIGN="center" BGCOLOR="#f7f7f7">1.2</TD>
# </TR>
# <TR>
# <TD CLASS="sort1" ALIGN="LEFT" BGCOLOR="#ffffff">&nbsp;39. <A HREF="/stats/players/15349/Maxx_Williams?LeagueID=">Maxx Williams</A></TD>
# <TD CLASS="sort1" ALIGN="center" BGCOLOR="#ffffff">BAL</TD>
# <TD CLASS="sort1" ALIGN="center" BGCOLOR="#ffffff">1</TD>
# <TD CLASS="sort1" ALIGN="center" BGCOLOR="#ffffff">1</TD>
# <TD CLASS="sort1" ALIGN="center" BGCOLOR="#ffffff">1</TD>
# <TD CLASS="sort1" ALIGN="center" BGCOLOR="#ffffff">12</TD>
# <TD CLASS="sort1" ALIGN="center" BGCOLOR="#ffffff">0</TD>
# <TD CLASS="sort1" ALIGN="center" BGCOLOR="#e0e0e0">1.2</TD>
# <TD CLASS="sort1" ALIGN="center" BGCOLOR="#ffffff">1.2</TD>
# </TR>
# <TR>
# <TD CLASS="sort1" ALIGN="LEFT" BGCOLOR="#f7f7f7">&nbsp;40. <A HREF="/stats/players/2612/Marcedes_Lewis?LeagueID=">Marcedes Lewis</A></TD>
# <TD CLASS="sort1" ALIGN="center" BGCOLOR="#f7f7f7">JAC</TD>
# <TD CLASS="sort1" ALIGN="center" BGCOLOR="#f7f7f7">1</TD>
# <TD CLASS="sort1" ALIGN="center" BGCOLOR="#f7f7f7">2</TD>
# <TD CLASS="sort1" ALIGN="center" BGCOLOR="#f7f7f7">1</TD>
# <TD CLASS="sort1" ALIGN="center" BGCOLOR="#f7f7f7">10</TD>
# <TD CLASS="sort1" ALIGN="center" BGCOLOR="#f7f7f7">0</TD>
# <TD CLASS="sort1" ALIGN="center" BGCOLOR="#e0e0e0">1.0</TD>
# <TD CLASS="sort1" ALIGN="center" BGCOLOR="#f7f7f7">1.0</TD>
# </TR>
# <TR>
# <TD CLASS="sort1" ALIGN="LEFT" BGCOLOR="#ffffff">&nbsp;41. <A HREF="/stats/players/2761/Greg_Olsen?LeagueID=">Greg Olsen</A></TD>
# <TD CLASS="sort1" ALIGN="center" BGCOLOR="#ffffff">CAR</TD>
# <TD CLASS="sort1" ALIGN="center" BGCOLOR="#ffffff">1</TD>
# <TD CLASS="sort1" ALIGN="center" BGCOLOR="#ffffff">4</TD>
# <TD CLASS="sort1" ALIGN="center" BGCOLOR="#ffffff">1</TD>
# <TD CLASS="sort1" ALIGN="center" BGCOLOR="#ffffff">10</TD>
# <TD CLASS="sort1" ALIGN="center" BGCOLOR="#ffffff">0</TD>
# <TD CLASS="sort1" ALIGN="center" BGCOLOR="#e0e0e0">1.0</TD>
# <TD CLASS="sort1" ALIGN="center" BGCOLOR="#ffffff">1.0</TD>
# </TR>
# <TR>
# <TD CLASS="sort1" ALIGN="LEFT" BGCOLOR="#f7f7f7">&nbsp;42. <A HREF="/stats/players/15120/Nick_Boyle?LeagueID=">Nick Boyle</A></TD>
# <TD CLASS="sort1" ALIGN="center" BGCOLOR="#f7f7f7">BAL</TD>
# <TD CLASS="sort1" ALIGN="center" BGCOLOR="#f7f7f7">1</TD>
# <TD CLASS="sort1" ALIGN="center" BGCOLOR="#f7f7f7">1</TD>
# <TD CLASS="sort1" ALIGN="center" BGCOLOR="#f7f7f7">1</TD>
# <TD CLASS="sort1" ALIGN="center" BGCOLOR="#f7f7f7">9</TD>
# <TD CLASS="sort1" ALIGN="center" BGCOLOR="#f7f7f7">0</TD>
# <TD CLASS="sort1" ALIGN="center" BGCOLOR="#e0e0e0">0.9</TD>
# <TD CLASS="sort1" ALIGN="center" BGCOLOR="#f7f7f7">0.9</TD>
# </TR>
# <TR>
# <TD CLASS="sort1" ALIGN="LEFT" BGCOLOR="#ffffff">&nbsp;43. <A HREF="/stats/players/12402/Rhett_Ellison?LeagueID=">Rhett Ellison</A></TD>
# <TD CLASS="sort1" ALIGN="center" BGCOLOR="#ffffff">NYG</TD>
# <TD CLASS="sort1" ALIGN="center" BGCOLOR="#ffffff">1</TD>
# <TD CLASS="sort1" ALIGN="center" BGCOLOR="#ffffff">1</TD>
# <TD CLASS="sort1" ALIGN="center" BGCOLOR="#ffffff">1</TD>
# <TD CLASS="sort1" ALIGN="center" BGCOLOR="#ffffff">9</TD>
# <TD CLASS="sort1" ALIGN="center" BGCOLOR="#ffffff">0</TD>
# <TD CLASS="sort1" ALIGN="center" BGCOLOR="#e0e0e0">0.9</TD>
# <TD CLASS="sort1" ALIGN="center" BGCOLOR="#ffffff">0.9</TD>
# </TR>
# <TR>
# <TD CLASS="sort1" ALIGN="LEFT" BGCOLOR="#f7f7f7">&nbsp;44. <A HREF="/stats/players/15865/Gerald_Everett?LeagueID=">Gerald Everett</A></TD>
# <TD CLASS="sort1" ALIGN="center" BGCOLOR="#f7f7f7">LAR</TD>
# <TD CLASS="sort1" ALIGN="center" BGCOLOR="#f7f7f7">1</TD>
# <TD CLASS="sort1" ALIGN="center" BGCOLOR="#f7f7f7">1</TD>
# <TD CLASS="sort1" ALIGN="center" BGCOLOR="#f7f7f7">1</TD>
# <TD CLASS="sort1" ALIGN="center" BGCOLOR="#f7f7f7">9</TD>
# <TD CLASS="sort1" ALIGN="center" BGCOLOR="#f7f7f7">0</TD>
# <TD CLASS="sort1" ALIGN="center" BGCOLOR="#e0e0e0">0.9</TD>
# <TD CLASS="sort1" ALIGN="center" BGCOLOR="#f7f7f7">0.9</TD>
# </TR>
# <TR>
# <TD CLASS="sort1" ALIGN="LEFT" BGCOLOR="#ffffff">&nbsp;45. <A HREF="/stats/players/12309/Coby_Fleener?LeagueID=">Coby Fleener</A></TD>
# <TD CLASS="sort1" ALIGN="center" BGCOLOR="#ffffff">NO</TD>
# <TD CLASS="sort1" ALIGN="center" BGCOLOR="#ffffff">1</TD>
# <TD CLASS="sort1" ALIGN="center" BGCOLOR="#ffffff">2</TD>
# <TD CLASS="sort1" ALIGN="center" BGCOLOR="#ffffff">1</TD>
# <TD CLASS="sort1" ALIGN="center" BGCOLOR="#ffffff">8</TD>
# <TD CLASS="sort1" ALIGN="center" BGCOLOR="#ffffff">0</TD>
# <TD CLASS="sort1" ALIGN="center" BGCOLOR="#e0e0e0">0.8</TD>
# <TD CLASS="sort1" ALIGN="center" BGCOLOR="#ffffff">0.8</TD>
# </TR>
# <TR>
# <TD CLASS="sort1" ALIGN="LEFT" BGCOLOR="#f7f7f7">&nbsp;46. <A HREF="/stats/players/14551/Garrett_Celek?LeagueID=">Garrett Celek</A></TD>
# <TD CLASS="sort1" ALIGN="center" BGCOLOR="#f7f7f7">SF</TD>
# <TD CLASS="sort1" ALIGN="center" BGCOLOR="#f7f7f7">1</TD>
# <TD CLASS="sort1" ALIGN="center" BGCOLOR="#f7f7f7">2</TD>
# <TD CLASS="sort1" ALIGN="center" BGCOLOR="#f7f7f7">2</TD>
# <TD CLASS="sort1" ALIGN="center" BGCOLOR="#f7f7f7">7</TD>
# <TD CLASS="sort1" ALIGN="center" BGCOLOR="#f7f7f7">0</TD>
# <TD CLASS="sort1" ALIGN="center" BGCOLOR="#e0e0e0">0.7</TD>
# <TD CLASS="sort1" ALIGN="center" BGCOLOR="#f7f7f7">0.7</TD>
# </TR>
# <TR>
# <TD CLASS="sort1" ALIGN="LEFT" BGCOLOR="#ffffff">&nbsp;47. <A HREF="/stats/players/15270/James_O'Shaughnessy?LeagueID=">James O'Shaughnessy</A></TD>
# <TD CLASS="sort1" ALIGN="center" BGCOLOR="#ffffff">JAC</TD>
# <TD CLASS="sort1" ALIGN="center" BGCOLOR="#ffffff">1</TD>
# <TD CLASS="sort1" ALIGN="center" BGCOLOR="#ffffff">2</TD>
# <TD CLASS="sort1" ALIGN="center" BGCOLOR="#ffffff">1</TD>
# <TD CLASS="sort1" ALIGN="center" BGCOLOR="#ffffff">7</TD>
# <TD CLASS="sort1" ALIGN="center" BGCOLOR="#ffffff">0</TD>
# <TD CLASS="sort1" ALIGN="center" BGCOLOR="#e0e0e0">0.7</TD>
# <TD CLASS="sort1" ALIGN="center" BGCOLOR="#ffffff">0.7</TD>
# </TR>
# <TR>
# <TD CLASS="sort1" ALIGN="LEFT" BGCOLOR="#f7f7f7">&nbsp;48. <A HREF="/stats/players/14543/Cameron_Brate?LeagueID=">Cameron Brate</A></TD>
# <TD CLASS="sort1" ALIGN="center" BGCOLOR="#f7f7f7">TB</TD>
# <TD CLASS="sort1" ALIGN="center" BGCOLOR="#f7f7f7">1</TD>
# <TD CLASS="sort1" ALIGN="center" BGCOLOR="#f7f7f7">2</TD>
# <TD CLASS="sort1" ALIGN="center" BGCOLOR="#f7f7f7">1</TD>
# <TD CLASS="sort1" ALIGN="center" BGCOLOR="#f7f7f7">6</TD>
# <TD CLASS="sort1" ALIGN="center" BGCOLOR="#f7f7f7">0</TD>
# <TD CLASS="sort1" ALIGN="center" BGCOLOR="#e0e0e0">0.6</TD>
# <TD CLASS="sort1" ALIGN="center" BGCOLOR="#f7f7f7">0.6</TD>
# </TR>
# <TR>
# <TD CLASS="sort1" ALIGN="LEFT" BGCOLOR="#ffffff">&nbsp;49. <A HREF="/stats/players/12338/Dwayne_Allen?LeagueID=">Dwayne Allen</A></TD>
# <TD CLASS="sort1" ALIGN="center" BGCOLOR="#ffffff">NE</TD>
# <TD CLASS="sort1" ALIGN="center" BGCOLOR="#ffffff">1</TD>
# <TD CLASS="sort1" ALIGN="center" BGCOLOR="#ffffff">2</TD>
# <TD CLASS="sort1" ALIGN="center" BGCOLOR="#ffffff">1</TD>
# <TD CLASS="sort1" ALIGN="center" BGCOLOR="#ffffff">2</TD>
# <TD CLASS="sort1" ALIGN="center" BGCOLOR="#ffffff">0</TD>
# <TD CLASS="sort1" ALIGN="center" BGCOLOR="#e0e0e0">0.2</TD>
# <TD CLASS="sort1" ALIGN="center" BGCOLOR="#ffffff">0.2</TD>
# </TR>
# <TR>
# <TD CLASS="sort1" ALIGN="LEFT" BGCOLOR="#f7f7f7">&nbsp;50. <A HREF="/stats/players/11089/Jared_Cook?LeagueID=">Jared Cook</A></TD>
# <TD CLASS="sort1" ALIGN="center" BGCOLOR="#f7f7f7">OAK</TD>
# <TD CLASS="sort1" ALIGN="center" BGCOLOR="#f7f7f7">1</TD>
# <TD CLASS="sort1" ALIGN="center" BGCOLOR="#f7f7f7">5</TD>
# <TD CLASS="sort1" ALIGN="center" BGCOLOR="#f7f7f7">1</TD>
# <TD CLASS="sort1" ALIGN="center" BGCOLOR="#f7f7f7">1</TD>
# <TD CLASS="sort1" ALIGN="center" BGCOLOR="#f7f7f7">0</TD>
# <TD CLASS="sort1" ALIGN="center" BGCOLOR="#e0e0e0">0.1</TD>
# <TD CLASS="sort1" ALIGN="center" BGCOLOR="#f7f7f7">0.1</TD>
# </TR>
#
# </TABLE>
# </td>
# </tr>
# </table><br>
# <div align='center'>
# <A HREF="?Season=2017&GameWeek=12&PosID=40&LeagueID=&order_by=FFPts&sort_order=DESC&cur_page=1">Next Page</A>  | <A HREF="?Season=2017&GameWeek=12&PosID=40&LeagueID=&order_by=FFPts&sort_order=DESC&cur_page=1">Last Page</A>
# </div>
#         <br>
#       </td>
#       <td align='center' valign='top' bgcolor='#f7f7f7' class='adcolumn'> <img src='/common/spacer_whi.gif' width='5' height='54'><br>
# 	  <!-- SMG_FFToday/160x600_1a/sports/fantasy/NFL.general -->
# <!-- --><div id="usmg_ad_NFL.general_fantasy_sports_160x600_1a">
# <script type='text/javascript'>
# googletag.defineSlot('/7103/SMG_FFToday/160x600_1a/sports/fantasy/NFL.general', [160,600], 'usmg_ad_NFL.general_fantasy_sports_160x600_1a').addService(googletag.pubads());
# googletag.enableServices();
# googletag.display('usmg_ad_NFL.general_fantasy_sports_160x600_1a');
# </script>
# </div>
# <!-- SMG_FFToday/160x600_1a/sports/fantasy/NFL.general end -->
#
# 	  	  <br>
#       </td>
#     </tr>
#   </table>
#
#   <!-- End Main Table -->
#
#    <!-- Footer ----------------------->
#     <table width='990' border='0' cellpadding='3' cellspacing='1'>
#                 <tr>
#                   <td valign="top" width="525">
# 	<div id="globalfooter">
#   <ul class="menu">
#     <li><a href="/about/index.htm">Company</a> -</li>
#     <li><a href="/privacy/index.htm">Privacy Policy</a> -</li>
#     <li><a href="/contact/index.htm">Contact</a> -</li>
#     <li><a href="/ad/index.htm">Advertise</a> -</li>
# 	<li><a href="/members/?r=myfftoday">Log In</a> -</li>
#     <li><a href="/signup_fftoday.php">Sign Up</a></li>
#   </ul>
#   <p id="copyright" align="left">Copyright &#169; 1998-2018 FFToday.com. All rights reserved.<br>
#   FFToday.com is a member of the <a href="http://www.fsta.org/">Fantasy Sports
#   Trade Association</a>.<br>
#   Partner of <a href="http://www.usatoday.com/sports/index">USA TODAY Sports Digital Properties</a>.</div></td>
# 	  <td valign='top' class='copyright' nowrap align='left' width='110'><img src='/common/spacer_whi.gif' width='1' height='20'><br><a href='http://twitter.com/FF_Today'><img src='/common/icn_twitter_follow_30.gif' width='99' height='30' border='0'></a></td>
#       <td valign='top' class='copyright' nowrap align='left' width='355'><img src='/common/spacer_whi.gif' width='1' height='20'><br><a href='http://www.facebook.com/fftoday'><img src='/common/icn_facebook_find_30.gif' width='99' height='30' border='0'></a></td>
# 	  </tr></table>
#
# <!-- SMG_FFToday/skin/sports/fantasy/NFL.general -->
#
#
# <!-- SMG_FFToday/skin/sports/fantasy/NFL.general end -->
#
# </center>
# </body>
#
# </html>

# %%
data = []
for tup in fftoday_urls():
    season, week, position, url = tup
    data.append((season, week, position, scrape(url)))
    time.sleep(DELAY)

# %%
print(data)
# Out:
# [(2017, 10, 20, <!DOCTYPE HTML PUBLIC "-//W3C//DTD HTML 4.0 Transitional//EN">
# <html>
# <head>
# <title>Running Back Stats: 2017 Week 10 - FF Today</title>
# <meta content="NFL and fantasy football stats from FF Today." name="description"/>
# <meta content="stats, statistics, nfl, fantasy football, quarterbacks, running backs, wide receivers, tight ends, defensive linemen, linebackers, defensive backs" name="keywords"/>
# <meta content="" property="og:image"/>
# <link href="/fftoday2.css" rel="STYLESHEET" type="text/css"/>
# <link href="/css/slimbox2.css" media="screen" rel="stylesheet" type="text/css"/>
# <link href="/themes/fft_default/style.css" media="print, projection, screen" rel="stylesheet" type="text/css"/>
# <script language="javascript" src="/rollOverColors.js" type="text/javascript"></script>
# <script src="/js/jquery.js" type="text/javascript"></script>
# <script src="/js/slimbox2.js" type="text/javascript"></script>
# <meta content="text/html; charset=utf-8" http-equiv="Content-Type"/>
# <script src="/js/jquery.tablesorter.js" type="text/javascript"></script>
# <script>
# $(document).ready(function()
#     {
#         $('#myTable').tablesorter();
#     }
# );
#
# // extend the default setting to always include the zebra widget.
#     $.tablesorter.defaults.widgets = ['zebra'];
# </script>
# <!-- Start DFP SETUP -->
# <script type="text/javascript"><!--
# //<![CDATA[
# (function() {
# var useSSL = 'https:' == document.location.protocol;
# var src = (useSSL ? 'https:' : 'http:') + '//www.googletagservices.com/tag/js/gpt.js';
# document.write('<scr' + 'ipt src="' + src + '"></scr' + 'ipt>');
# })();
# //]]>
# //--></script>
# <script src="http://img.bnqt.com/lib/js/sdpdfphelper.js" type="text/javascript"></script>
# <script type="text/javascript">
# googletag.pubads().enableSyncRendering();
# googletag.pubads().setTargeting("title", sdpTargeting.title)
#                   .setTargeting('targetPaths', sdpTargeting.targetPaths)
#                   .setTargeting('fullPath', sdpTargeting.fullPath)
#                   .setTargeting('queryStr', sdpTargeting.queryStr)
#                   .setTargeting('domainName', sdpTargeting.domainName);
# </script>
# <script type="text/javascript">
# window._UrlSegment = window._UrlSegment || '';
# window._SitePage = window._SitePage || '';
# _UrlSegment = window.location.toString().replace(/http:\/\//, '').split('/');
# _SitePage = _UrlSegment[1].match(/^$|^(index.php)+$/i) ? 'main' : 'general';
# </script>
# <!-- End DFP SETUP -->
# <!-- Begin comScore Tag -->
# <script>
#   var _comscore = _comscore || [];
#   _comscore.push({ c1: "2", c2: "6035210" });
#   (function() {
#     var s = document.createElement("script"), el = document.getElementsByTagName("script")[0]; s.async = true;
#     s.src = (document.location.protocol == "https:" ? "https://sb" : "http://b") + ".scorecardresearch.com/beacon.js";
#     el.parentNode.insertBefore(s, el);
#   })();
# </script>
# <noscript>
# <img src="http://b.scorecardresearch.com/p?c1=2&amp;c2=6035210&amp;cv=2.0&amp;cj=1"/>
# </noscript>
# <!-- End comScore Tag -->
# <!-- Begin Google Analytics -->
# <script type="text/javascript">
#
#   var _gaq = _gaq || [];
#   _gaq.push(['_setAccount', 'UA-37923979-1']);
#   _gaq.push(['_setDomainName', 'fftoday.com']);
#   _gaq.push(['_setAllowLinker', true]);
#   _gaq.push(['_trackPageview']);
#
#   (function() {
#     var ga = document.createElement('script'); ga.type = 'text/javascript'; ga.async = true;
#     ga.src = ('https:' == document.location.protocol ? 'https://ssl' : 'http://www') + '.google-analytics.com/ga.js';
#     var s = document.getElementsByTagName('script')[0]; s.parentNode.insertBefore(ga, s);
#   })();
#
# </script>
# <!-- End Google Analytics -->
# <!-- Social Share Buttons -->
# <script>!function(d,s,id){var js,fjs=d.getElementsByTagName(s)[0];if(!d.getElementById(id)){js=d.createElement(s);js.id=id;js.src='https://platform.twitter.com/widgets.js';fjs.parentNode.insertBefore(js,fjs);}}(document,'script','twitter-wjs');</script>
# </head><body><div id="fb-root"></div>
# <script>(function(d, s, id) {
#   var js, fjs = d.getElementsByTagName(s)[0];
#   if (d.getElementById(id)) return;
#   js = d.createElement(s); js.id = id;
#   js.src = '//connect.facebook.net/en_US/sdk.js#xfbml=1&version=v2.10';
#   fjs.parentNode.insertBefore(js, fjs);
# }(document, 'script', 'facebook-jssdk'));</script>
# <!-- End Social Share Buttons -->
# <center>
# <table align="center" bgcolor="#FFFFFF" border="0" cellpadding="0" cellspacing="0" width="990">
# <tr>
# <td bgcolor="#FFFFFF" rowspan="2" valign="top" width="10"> </td>
# <td rowspan="2" valign="top" width="220"><img height="5" src="/common/spacer_whi.gif" width="2"/><br/>
# <a href="/index.html"><img alt="Fantasy Football Today - fantasy football rankings, cheatsheets, and information" border="0" height="106" src="/creative/08_179_fftoday.gif" width="179"/></a><br/>
# <span class="logotease">A Fantasy Football Community!</span><br/>
# <!-- Todays Date -->
# <img height="5" src="/common/spacer_whi.gif" width="1"/><br/>
# <span class="date">
# <!-- Todays Date -->
# <script language="JavaScript"><!--
#        var DayOfWeek = new Array('Sunday','Monday','Tuesday','Wednesday','Thursday','Friday','Saturday');
#        var MonthName = new Array('January','February','March','April','May','June','July','August','September',
#                           'October','November','December');
#        var theDate = new Date();
#        document.write('<NOBR>' +
#                DayOfWeek[theDate.getDay()] + ', ' +
# 			   MonthName[theDate.getMonth()] + ' ' +
#                theDate.getDate() + ', 2018' +
#
#               '</font></NOBR>');
#         //--></script><br/><img height="3" src="/common/spacer_whi.gif" width="2"/><br/></span></td>
# <td align="center" valign="top"><img height="5" src="/common/spacer_whi.gif" width="2"/><br/>
# <!-- SMG_FFToday/728x90_1a/sports/fantasy/NFL.general -->
# <!-- --> <div id="usmg_ad_NFL.general_fantasy_sports_728x90_1a">
# <script type="text/javascript">
# googletag.defineSlot('/7103/SMG_FFToday/728x90_1a/sports/fantasy/NFL.general', [728,90], 'usmg_ad_NFL.general_fantasy_sports_728x90_1a').addService(googletag.pubads());
# googletag.enableServices();
# googletag.display('usmg_ad_NFL.general_fantasy_sports_728x90_1a');
# </script>
# </div>
# <!-- SMG_FFToday/728x90_1a/sports/fantasy/NFL.general end -->
# </td>
# </tr>
# <tr>
# <td align="right" class="date" rowspan="2" valign="bottom"> <a href="http://www.fftoday.com/members/?r=myfftoday">Log In</a>  | <a href="http://www.fftoday.com/signup_fftoday.php">Sign Up</a>  |  <a href="http://www.fftoday.com/contact/index.htm">Contact</a>      <br/>
# <img height="5" src="/common/spacer_whi.gif" width="2"/><br/> <table border="0" cellpadding="0" cellspacing="0" width="100%">
# <form action="http://sub.ezinedirector.net/index.cfm" method="post">
# <input name="fuseaction" type="hidden" value="s"/>
# <input name="EzineID" type="hidden" value="964693455"/>
# <tr valign="center">
# <td> <table align="right" border="0" cellpadding="0" cellspacing="0" height="20" width="275">
# <tr>
# <td class="navhdrnewsletter" nowrap="">Free Newsletter!</td>
# <td nowrap=""><img align="top" height="20" src="/common/blank2.gif" width="5"/></td>
# <td><input class="input" maxlength="255" name="email" type="text" value=" enter email address"/></td>
# <td><img border="0" height="20" src="/common/blank2.gif" width="5"/></td>
# <td valign="top"> <input alt="Submit" border="0" hspace="0" name="image" src="/common/btn_go_white.gif" type="image" value="submit" vspace="0"/></td>
# <td><img border="0" height="20" src="/common/blank2.gif" width="20"/></td>
# </tr>
# </table></td>
# </tr>
# </form>
# </table> </td>
# </tr>
# </table>
# <!-- End Logo/Leaderboard Table -->
# <div class="nav">
# <ul>
# <li id="mArticles"><a href="/articles/index.htm">articles</a></li>
# <li id="mRankings_Projections"><a href="/rankings/index.html">rankings / projections</a></li>
# <li id="mNews"><a href="/news/index.php">news</a></li>
# <li id="mContests"><a href="/contests/index.php">contests</a></li>
# <li id="mPlayers"><a href="/stats/players">players</a></li>
# <li id="mStats"><a href="/stats/index.htm">stats</a></li>
# <li id="mTools"><a href="/tools/index.htm">tools</a></li>
# <li id="mNFL_Resources"><a href="/nfl/index.htm">nfl resources</a></li>
# <li id="mForums"><a href="http://www.fftodayforums.com/">forums</a></li>
# <li id="mMy_FFToday"><a href="/myfftoday/index.php">my fftoday</a></li>
# </ul>
# <div class="clear"></div>
# </div>
# <!-- SMG_FFToday/launchpad/sports/fantasy/NFL.general -->
# <!-- SMG_FFToday/launchpad/sports/fantasy/NFL.general end -->
# <table align="center" bgcolor="white" border="0" cellpadding="0" cellspacing="0" width="990">
# <tr>
# <td bgcolor="#ffffff" rowspan="2" valign="top" width="20"><img height="2" src="/common/spacer_whi.gif" width="20"/><br/>
# </td>
# <td align="right" valign="top" width="770"><img height="2" src="/common/spacer_whi.gif" width="5"/><br/>
# </td>
# <td bgcolor="#ffffff" rowspan="2" valign="top" width="20"><img height="2" src="/common/spacer_whi.gif" width="20"/><br/>
# </td>
# <td align="center" class="adcolumn" valign="top" width="180"><img height="2" src="/common/spacer_whi.gif" width="5"/><br/>
# </td>
# </tr>
# <tr>
# <td class="bodycontent" valign="top"><table border="0" cellpadding="0" cellspacing="0" width="100%">
# <tr>
# <td width="100%"> <span class="breadcrumb"><a class="breadcrumb" href="../stats/index.htm">Stats</a> &gt; Player Stats</span></td>
# <td align="right" nowrap="">  </td>
# </tr>
# </table><img height="10" src="/common/spacer_whi.gif" width="5"/><table border="0" cellpadding="3" cellspacing="1" width="100%">
# <tr>
# <td class="pageheader">Running Back Stats: 2017</td>
# <td align="right" class="date" nowrap="" valign="bottom"> </td>
# </tr>
# <tr>
# <td colspan="2"><img height="1" src="/common/hdr_nav_tile_black3.gif" width="765"/></td>
# </tr>
# <tr>
# <td class="update" colspan="2" width="100%"> Week 10<br/></td>
# </tr>
# </table>
# <img alt="" border="0" height="4" src="/common/spacer_whi.gif" width="1"/><br/>
# <!-- Begin Content Table------------------------------------------------->
# <table class="bodycontent"><tr><td>
# <strong>Want Custom Fantasy Scoring?</strong><br/>
# You are not logged in. You must be logged in and create a league profile to apply
# custom fantasy scoring to the stats, projections and rankings pages.
# <a href="../members/?r=playerstats">Login</a> or <a href="../signup.php?r=playerstats">Register</a>
# </td></tr></table>
# <br/><table class="navstats">
# <tr>
# <td><strong>Position: </strong></td>
# <td><a href="?Season=2017&amp;GameWeek=10&amp;PosID=10&amp;LeagueID=">QB</a> |
# 		<a href="?Season=2017&amp;GameWeek=10&amp;PosID=20&amp;LeagueID=">RB</a> |
# 		<a href="?Season=2017&amp;GameWeek=10&amp;PosID=30&amp;LeagueID=">WR</a> |
# 		<a href="?Season=2017&amp;GameWeek=10&amp;PosID=40&amp;LeagueID=">TE</a> |
# 		<a href="?Season=2017&amp;GameWeek=10&amp;PosID=80&amp;LeagueID=">K</a> |
# 		<a href="?Season=2017&amp;GameWeek=10&amp;PosID=99&amp;LeagueID=">DEF</a> |
# 		<a href="?Season=2017&amp;GameWeek=10&amp;PosID=50&amp;LeagueID=">DL</a> |
# 		<a href="?Season=2017&amp;GameWeek=10&amp;PosID=60&amp;LeagueID=">LB</a> |
# 		<a href="?Season=2017&amp;GameWeek=10&amp;PosID=70&amp;LeagueID=">DB</a></td>
# </tr>
# <tr>
# <td><strong>Season: </strong></td>
# <td><a href="?Season=2017&amp;GameWeek=10&amp;PosID=20&amp;LeagueID=">2017</a> |
# 		<a href="?Season=2016&amp;GameWeek=10&amp;PosID=20&amp;LeagueID=">2016</a> |
# 		<a href="?Season=2015&amp;GameWeek=10&amp;PosID=20&amp;LeagueID=">2015</a> |
# 		<a href="?Season=2014&amp;GameWeek=10&amp;PosID=20&amp;LeagueID=">2014</a> |
# 		<a href="?Season=2013&amp;GameWeek=10&amp;PosID=20&amp;LeagueID=">2013</a> |
# 		<a href="?Season=2012&amp;GameWeek=10&amp;PosID=20&amp;LeagueID=">2012</a> |
# 		<a href="?Season=2011&amp;GameWeek=10&amp;PosID=20&amp;LeagueID=">2011</a> |
# 		<a href="?Season=2010&amp;GameWeek=10&amp;PosID=20&amp;LeagueID=">2010</a> |
# 		<a href="?Season=2009&amp;GameWeek=10&amp;PosID=20&amp;LeagueID=">2009</a> |
# 		<a href="?Season=2008&amp;GameWeek=10&amp;PosID=20&amp;LeagueID=">2008</a> |
# 		<a href="?Season=2007&amp;GameWeek=10&amp;PosID=20&amp;LeagueID=">2007</a> |
# 		<a href="?Season=2006&amp;GameWeek=10&amp;PosID=20&amp;LeagueID=">2006</a> |
# 		<a href="?Season=2005&amp;GameWeek=10&amp;PosID=20&amp;LeagueID=">2005</a> |
# 		<a href="?Season=2004&amp;GameWeek=10&amp;PosID=20&amp;LeagueID=">2004</a> |
# 		<a href="?Season=2003&amp;GameWeek=10&amp;PosID=20&amp;LeagueID=">2003</a> |
# 		<a href="?Season=2002&amp;GameWeek=10&amp;PosID=20&amp;LeagueID=">2002</a> |
# 		<a href="?Season=2001&amp;GameWeek=10&amp;PosID=20&amp;LeagueID=">2001</a>
# </td>
# </tr>
# <tr>
# <td><strong>Week: </strong></td>
# <td><a href="?Season=2017&amp;GameWeek=1&amp;PosID=20&amp;LeagueID=">1</a> |
# 		<a href="?Season=2017&amp;GameWeek=2&amp;PosID=20&amp;LeagueID=">2</a> |
# 		<a href="?Season=2017&amp;GameWeek=3&amp;PosID=20&amp;LeagueID=">3</a> |
# 		<a href="?Season=2017&amp;GameWeek=4&amp;PosID=20&amp;LeagueID=">4</a> |
# 		<a href="?Season=2017&amp;GameWeek=5&amp;PosID=20&amp;LeagueID=">5</a> |
# 		<a href="?Season=2017&amp;GameWeek=6&amp;PosID=20&amp;LeagueID=">6</a> |
# 		<a href="?Season=2017&amp;GameWeek=7&amp;PosID=20&amp;LeagueID=">7</a> |
# 		<a href="?Season=2017&amp;GameWeek=8&amp;PosID=20&amp;LeagueID=">8</a> |
# 		<a href="?Season=2017&amp;GameWeek=9&amp;PosID=20&amp;LeagueID=">9</a> |
# 		<a href="?Season=2017&amp;GameWeek=10&amp;PosID=20&amp;LeagueID=">10</a> |
# 		<a href="?Season=2017&amp;GameWeek=11&amp;PosID=20&amp;LeagueID=">11</a> |
# 		<a href="?Season=2017&amp;GameWeek=12&amp;PosID=20&amp;LeagueID=">12</a> |
# 		<a href="?Season=2017&amp;GameWeek=13&amp;PosID=20&amp;LeagueID=">13</a> |
# 		<a href="?Season=2017&amp;GameWeek=14&amp;PosID=20&amp;LeagueID=">14</a> |
# 		<a href="?Season=2017&amp;GameWeek=15&amp;PosID=20&amp;LeagueID=">15</a> |
# 		<a href="?Season=2017&amp;GameWeek=16&amp;PosID=20&amp;LeagueID=">16</a> |
# 		<a href="?Season=2017&amp;GameWeek=17&amp;PosID=20&amp;LeagueID=">17</a></td>
# </tr>
# <tr>
# <td><strong>Playoffs: </strong></td>
# <td><a href="?Season=2017&amp;GameWeek=21&amp;PosID=20&amp;LeagueID=">Wild-Card</a> |
# 		<a href="?Season=2017&amp;GameWeek=22&amp;PosID=20&amp;LeagueID=">Divisional Playoffs</a> |
# 		<a href="?Season=2017&amp;GameWeek=23&amp;PosID=20&amp;LeagueID=">Conference Championships</a> |
# 		<a href="?Season=2017&amp;GameWeek=24&amp;PosID=20&amp;LeagueID=">Super Bowl</a></td>
# </tr>
# <tr>
# <td><strong>Options: </strong></td>
# <td><a href="?Season=2017&amp;GameWeek=Last3&amp;PosID=20&amp;LeagueID=">Last 3 Weeks</a> |
# 		<a href="?Season=2017&amp;GameWeek=Last5&amp;PosID=20&amp;LeagueID=">Last 5 Weeks</a> |
# 		<a href="?Season=2017&amp;GameWeek=Season&amp;PosID=20&amp;LeagueID=">Season</a> |
# 		<a href="?Season=2017&amp;GameWeek=Playoffs&amp;PosID=20&amp;LeagueID=">Playoffs</a></td>
# </tr>
# </table>
# <br/>
# <script language="JavaScript" type="text/javascript">
#  <!--
#  function reviewscoring_pop() { window.open('../myfftoday/reviewscoring.php?LeagueID=&PosID=20','ReviewScoring','width=250,height=400,resizable=yes,scrollbars=yes'); }
#  //-->
#  </script>
# <table border="0" cellpadding="1" cellspacing="1" width="100%">
# <form action="" method="get" name="PlayerStats">
# <input name="Season" type="hidden" value="2017"/>
# <input name="GameWeek" type="hidden" value="10"/>
# <input name="PosID" type="hidden" value="20"/>
# <tr>
# <td align="left" nowrap="" valign="top"><span class="smallbody">FF Today Standard Scoring: <a href="javascript:reviewscoring_pop();">Review Scoring</a></span></td>
# <td align="right" valign="top">
# <select class="articledrop" name="LeagueID" onchange="this.form.submit();">
# <option value="">   My FF Today </option>
# <option value=""></option>
# <option value="">&gt; Pre-Set Scoring </option>
# <option value="1">   FF Today Standard</option>
# <option value="107644">   FF Today PPR</option>
# <option value="193033">   FF Today Half-Point PPR</option>
# <option value="26943">   CBS Sports</option>
# <option value="26955">   ESPN</option>
# <option value="17">   Yahoo!</option>
# <option value="143908">   NFL.com</option>
# <option value="107437">   FFPC</option>
# <option value="5">   NFFC</option></select></td>
# </tr>
# </form>
# </table><table border="0" cellpadding="0" cellspacing="0" width="100%">
# <tr bgcolor="#eeeeee">
# <td>
# <table border="0" cellpadding="2" cellspacing="1" width="100%">
# <tr class="tablehdr">
# <td align="left" colspan="3" nowrap="" valign="middle">  </td>
# <td align="center" colspan="3" nowrap="">Rushing</td><td align="center" colspan="4" nowrap="">Receiving</td>
# <td align="center" bgcolor="#666666" colspan="2" nowrap="">Fantasy</td>
# </tr>
# <tr class="tableclmhdr">
# <td align="center" nowrap="" valign="middle"><b>Player</b><br/>
# <span class="tableclmhdrsort">Sort First: <a href="?Season=2017&amp;GameWeek=10&amp;PosID=20&amp;LeagueID=&amp;order_by=FName&amp;sort_order=ASC">
# <img align="absbottom" border="0" height="14" src="../images/asc.gif" width="11"/></a>
# <a href="?Season=2017&amp;GameWeek=10&amp;PosID=20&amp;LeagueID=&amp;order_by=FName&amp;sort_order=DESC">
# <img align="absbottom" border="0" height="14" src="../images/desc.gif" width="11"/></a>
# 		Last: <a href="?Season=2017&amp;GameWeek=10&amp;PosID=20&amp;LeagueID=&amp;order_by=LName&amp;sort_order=ASC">
# <img align="absbottom" border="0" height="14" src="../images/asc.gif" width="11"/></a>
# <a href="?Season=2017&amp;GameWeek=10&amp;PosID=20&amp;LeagueID=&amp;order_by=LName&amp;sort_order=DESC">
# <img align="absbottom" border="0" height="14" src="../images/desc.gif" width="11"/></a></span></td>
# <td align="center" nowrap=""><b>Team</b><br/>
# <a href="?Season=2017&amp;GameWeek=10&amp;PosID=20&amp;LeagueID=&amp;order_by=TeamAbb&amp;sort_order=ASC">
# <img border="0" height="14" src="../images/asc.gif" width="11"/></a>
# <a href="?Season=2017&amp;GameWeek=10&amp;PosID=20&amp;LeagueID=&amp;order_by=TeamAbb&amp;sort_order=DESC">
# <img border="0" height="14" src="../images/desc.gif" width="11"/></a></td>
# <td align="center" nowrap=""><b>G</b><br/>
# <a href="?Season=2017&amp;GameWeek=10&amp;PosID=20&amp;LeagueID=&amp;order_by=Play&amp;sort_order=ASC">
# <img border="0" height="14" src="../images/asc.gif" width="11"/></a>
# <a href="?Season=2017&amp;GameWeek=10&amp;PosID=20&amp;LeagueID=&amp;order_by=Play&amp;sort_order=DESC">
# <img border="0" height="14" src="../images/desc.gif" width="11"/></a></td>
# <!--
# 		<TD ALIGN='center' NOWRAP><B>GS</B><BR>
# 		<A HREF='?Season=2017&GameWeek=10&PosID=20&LeagueID=&order_by=Start&sort_order=ASC'>
# 		<IMG SRC='../images/asc.gif' WIDTH='11' HEIGHT='14' BORDER='0'></A>
# 		<A HREF='?Season=2017&GameWeek=10&PosID=20&LeagueID=&order_by=Start&sort_order=DESC'>
# 		<IMG SRC='../images/desc.gif' WIDTH='11' HEIGHT='14' BORDER='0'></A></TD>
# 		-->
# <td align="center" bgcolor="#e0e0e0" nowrap=""><b>Att</b><br/>
# <a href="?Season=2017&amp;GameWeek=10&amp;PosID=20&amp;LeagueID=&amp;order_by=RuAtt&amp;sort_order=ASC"><img border="0" height="14" src="../images/asc.gif" width="11"/></a>
# <a href="?Season=2017&amp;GameWeek=10&amp;PosID=20&amp;LeagueID=&amp;order_by=RuAtt&amp;sort_order=DESC"><img border="0" height="14" src="../images/desc.gif" width="11"/></a></td>
# <td align="center" bgcolor="#e0e0e0" nowrap=""><b>Yard</b><br/>
# <a href="?Season=2017&amp;GameWeek=10&amp;PosID=20&amp;LeagueID=&amp;order_by=RuYd&amp;sort_order=ASC"><img border="0" height="14" src="../images/asc.gif" width="11"/></a>
# <a href="?Season=2017&amp;GameWeek=10&amp;PosID=20&amp;LeagueID=&amp;order_by=RuYd&amp;sort_order=DESC"><img border="0" height="14" src="../images/desc.gif" width="11"/></a></td>
# <td align="center" bgcolor="#e0e0e0" nowrap=""><b>TD</b><br/>
# <a href="?Season=2017&amp;GameWeek=10&amp;PosID=20&amp;LeagueID=&amp;order_by=RuTd&amp;sort_order=ASC"><img border="0" height="14" src="../images/asc.gif" width="11"/></a>
# <a href="?Season=2017&amp;GameWeek=10&amp;PosID=20&amp;LeagueID=&amp;order_by=RuTD&amp;sort_order=DESC"><img border="0" height="14" src="../images/desc.gif" width="11"/></a></td><td align="center" bgcolor="#e0e0e0" nowrap=""><b>Target</b><br/>
# <a href="?Season=2017&amp;GameWeek=10&amp;PosID=20&amp;LeagueID=&amp;order_by=Target&amp;sort_order=ASC"><img border="0" height="14" src="../images/asc.gif" width="11"/></a>
# <a href="?Season=2017&amp;GameWeek=10&amp;PosID=20&amp;LeagueID=&amp;order_by=Target&amp;sort_order=DESC"><img border="0" height="14" src="../images/desc.gif" width="11"/></a></td>
# <td align="center" bgcolor="#e0e0e0" nowrap=""><b>Rec</b><br/>
# <a href="?Season=2017&amp;GameWeek=10&amp;PosID=20&amp;LeagueID=&amp;order_by=Rec&amp;sort_order=ASC"><img border="0" height="14" src="../images/asc.gif" width="11"/></a>
# <a href="?Season=2017&amp;GameWeek=10&amp;PosID=20&amp;LeagueID=&amp;order_by=Rec&amp;sort_order=DESC"><img border="0" height="14" src="../images/desc.gif" width="11"/></a></td>
# <td align="center" bgcolor="#e0e0e0" nowrap=""><b>Yard</b><br/>
# <a href="?Season=2017&amp;GameWeek=10&amp;PosID=20&amp;LeagueID=&amp;order_by=ReYd&amp;sort_order=ASC"><img border="0" height="14" src="../images/asc.gif" width="11"/></a>
# <a href="?Season=2017&amp;GameWeek=10&amp;PosID=20&amp;LeagueID=&amp;order_by=ReYd&amp;sort_order=DESC"><img border="0" height="14" src="../images/desc.gif" width="11"/></a></td>
# <td align="center" bgcolor="#e0e0e0" nowrap=""><b>TD</b><br/>
# <a href="?Season=2017&amp;GameWeek=10&amp;PosID=20&amp;LeagueID=&amp;order_by=ReTD&amp;sort_order=ASC"><img border="0" height="14" src="../images/asc.gif" width="11"/></a>
# <a href="?Season=2017&amp;GameWeek=10&amp;PosID=20&amp;LeagueID=&amp;order_by=ReTD&amp;sort_order=DESC"><img border="0" height="14" src="../images/desc.gif" width="11"/></a></td>
# <td align="center" nowrap=""><b>FPts</b><br/>
# <a href="?Season=2017&amp;GameWeek=10&amp;PosID=20&amp;LeagueID=&amp;order_by=FFPts&amp;sort_order=ASC">
# <img border="0" height="14" src="../images/asc.gif" width="11"/></a>
# <a href="?Season=2017&amp;GameWeek=10&amp;PosID=20&amp;LeagueID=&amp;order_by=FFPts&amp;sort_order=DESC">
# <img border="0" height="14" src="../images/desc.gif" width="11"/></a></td>
# <td align="center" nowrap=""><b>FPts/G</b><br/>
# <a href="?Season=2017&amp;GameWeek=10&amp;PosID=20&amp;LeagueID=&amp;order_by=FFPtsPerG&amp;sort_order=ASC">
# <img border="0" height="14" src="../images/asc.gif" width="11"/></a>
# <a href="?Season=2017&amp;GameWeek=10&amp;PosID=20&amp;LeagueID=&amp;order_by=FFPtsPerG&amp;sort_order=DESC">
# <img border="0" height="14" src="../images/desc.gif" width="11"/></a></td>
# </tr>
# <tr>
# <td align="LEFT" bgcolor="#ffffff" class="sort1"> 1. <a href="/stats/players/11882/Mark_Ingram?LeagueID=">Mark Ingram</a></td>
# <td align="center" bgcolor="#ffffff" class="sort1">NO</td>
# <td align="center" bgcolor="#ffffff" class="sort1">1</td>
# <td align="center" bgcolor="#ffffff" class="sort1">21</td>
# <td align="center" bgcolor="#ffffff" class="sort1">131</td>
# <td align="center" bgcolor="#ffffff" class="sort1">3</td>
# <td align="center" bgcolor="#ffffff" class="sort1">0</td>
# <td align="center" bgcolor="#ffffff" class="sort1">0</td>
# <td align="center" bgcolor="#ffffff" class="sort1">0</td>
# <td align="center" bgcolor="#ffffff" class="sort1">0</td>
# <td align="center" bgcolor="#e0e0e0" class="sort1">31.1</td>
# <td align="center" bgcolor="#ffffff" class="sort1">31.1</td>
# </tr>
# <tr>
# <td align="LEFT" bgcolor="#f7f7f7" class="sort1"> 2. <a href="/stats/players/11925/DeMarco_Murray?LeagueID=">DeMarco Murray</a></td>
# <td align="center" bgcolor="#f7f7f7" class="sort1">TEN</td>
# <td align="center" bgcolor="#f7f7f7" class="sort1">1</td>
# <td align="center" bgcolor="#f7f7f7" class="sort1">14</td>
# <td align="center" bgcolor="#f7f7f7" class="sort1">42</td>
# <td align="center" bgcolor="#f7f7f7" class="sort1">2</td>
# <td align="center" bgcolor="#f7f7f7" class="sort1">4</td>
# <td align="center" bgcolor="#f7f7f7" class="sort1">4</td>
# <td align="center" bgcolor="#f7f7f7" class="sort1">30</td>
# <td align="center" bgcolor="#f7f7f7" class="sort1">1</td>
# <td align="center" bgcolor="#e0e0e0" class="sort1">25.2</td>
# <td align="center" bgcolor="#f7f7f7" class="sort1">25.2</td>
# </tr>
# <tr>
# <td align="LEFT" bgcolor="#ffffff" class="sort1"> 3. <a href="/stats/players/14936/Austin_Ekeler?LeagueID=">Austin Ekeler</a></td>
# <td align="center" bgcolor="#ffffff" class="sort1">LAC</td>
# <td align="center" bgcolor="#ffffff" class="sort1">1</td>
# <td align="center" bgcolor="#ffffff" class="sort1">10</td>
# <td align="center" bgcolor="#ffffff" class="sort1">42</td>
# <td align="center" bgcolor="#ffffff" class="sort1">0</td>
# <td align="center" bgcolor="#ffffff" class="sort1">5</td>
# <td align="center" bgcolor="#ffffff" class="sort1">5</td>
# <td align="center" bgcolor="#ffffff" class="sort1">77</td>
# <td align="center" bgcolor="#ffffff" class="sort1">2</td>
# <td align="center" bgcolor="#e0e0e0" class="sort1">23.9</td>
# <td align="center" bgcolor="#ffffff" class="sort1">23.9</td>
# </tr>
# <tr>
# <td align="LEFT" bgcolor="#f7f7f7" class="sort1"> 4. <a href="/stats/players/15924/Alvin_Kamara?LeagueID=">Alvin Kamara</a></td>
# <td align="center" bgcolor="#f7f7f7" class="sort1">NO</td>
# <td align="center" bgcolor="#f7f7f7" class="sort1">1</td>
# <td align="center" bgcolor="#f7f7f7" class="sort1">12</td>
# <td align="center" bgcolor="#f7f7f7" class="sort1">106</td>
# <td align="center" bgcolor="#f7f7f7" class="sort1">1</td>
# <td align="center" bgcolor="#f7f7f7" class="sort1">5</td>
# <td align="center" bgcolor="#f7f7f7" class="sort1">5</td>
# <td align="center" bgcolor="#f7f7f7" class="sort1">32</td>
# <td align="center" bgcolor="#f7f7f7" class="sort1">0</td>
# <td align="center" bgcolor="#e0e0e0" class="sort1">19.8</td>
# <td align="center" bgcolor="#f7f7f7" class="sort1">19.8</td>
# </tr>
# <tr>
# <td align="LEFT" bgcolor="#ffffff" class="sort1"> 5. <a href="/stats/players/15950/Christian_McCaffrey?LeagueID=">Christian McCaffrey</a></td>
# <td align="center" bgcolor="#ffffff" class="sort1">CAR</td>
# <td align="center" bgcolor="#ffffff" class="sort1">1</td>
# <td align="center" bgcolor="#ffffff" class="sort1">5</td>
# <td align="center" bgcolor="#ffffff" class="sort1">23</td>
# <td align="center" bgcolor="#ffffff" class="sort1">1</td>
# <td align="center" bgcolor="#ffffff" class="sort1">7</td>
# <td align="center" bgcolor="#ffffff" class="sort1">3</td>
# <td align="center" bgcolor="#ffffff" class="sort1">27</td>
# <td align="center" bgcolor="#ffffff" class="sort1">1</td>
# <td align="center" bgcolor="#e0e0e0" class="sort1">17.0</td>
# <td align="center" bgcolor="#ffffff" class="sort1">17.0</td>
# </tr>
# <tr>
# <td align="LEFT" bgcolor="#f7f7f7" class="sort1"> 6. <a href="/stats/players/14381/Isaiah_Crowell?LeagueID=">Isaiah Crowell</a></td>
# <td align="center" bgcolor="#f7f7f7" class="sort1">CLE</td>
# <td align="center" bgcolor="#f7f7f7" class="sort1">1</td>
# <td align="center" bgcolor="#f7f7f7" class="sort1">16</td>
# <td align="center" bgcolor="#f7f7f7" class="sort1">90</td>
# <td align="center" bgcolor="#f7f7f7" class="sort1">1</td>
# <td align="center" bgcolor="#f7f7f7" class="sort1">2</td>
# <td align="center" bgcolor="#f7f7f7" class="sort1">1</td>
# <td align="center" bgcolor="#f7f7f7" class="sort1">5</td>
# <td align="center" bgcolor="#f7f7f7" class="sort1">0</td>
# <td align="center" bgcolor="#e0e0e0" class="sort1">15.5</td>
# <td align="center" bgcolor="#f7f7f7" class="sort1">15.5</td>
# </tr>
# <tr>
# <td align="LEFT" bgcolor="#ffffff" class="sort1"> 7. <a href="/stats/players/15569/Kenyan_Drake?LeagueID=">Kenyan Drake</a></td>
# <td align="center" bgcolor="#ffffff" class="sort1">MIA</td>
# <td align="center" bgcolor="#ffffff" class="sort1">1</td>
# <td align="center" bgcolor="#ffffff" class="sort1">7</td>
# <td align="center" bgcolor="#ffffff" class="sort1">82</td>
# <td align="center" bgcolor="#ffffff" class="sort1">1</td>
# <td align="center" bgcolor="#ffffff" class="sort1">2</td>
# <td align="center" bgcolor="#ffffff" class="sort1">2</td>
# <td align="center" bgcolor="#ffffff" class="sort1">10</td>
# <td align="center" bgcolor="#ffffff" class="sort1">0</td>
# <td align="center" bgcolor="#e0e0e0" class="sort1">15.2</td>
# <td align="center" bgcolor="#ffffff" class="sort1">15.2</td>
# </tr>
# <tr>
# <td align="LEFT" bgcolor="#f7f7f7" class="sort1"> 8. <a href="/stats/players/15138/Tevin_Coleman?LeagueID=">Tevin Coleman</a></td>
# <td align="center" bgcolor="#f7f7f7" class="sort1">ATL</td>
# <td align="center" bgcolor="#f7f7f7" class="sort1">1</td>
# <td align="center" bgcolor="#f7f7f7" class="sort1">20</td>
# <td align="center" bgcolor="#f7f7f7" class="sort1">83</td>
# <td align="center" bgcolor="#f7f7f7" class="sort1">1</td>
# <td align="center" bgcolor="#f7f7f7" class="sort1">1</td>
# <td align="center" bgcolor="#f7f7f7" class="sort1">1</td>
# <td align="center" bgcolor="#f7f7f7" class="sort1">5</td>
# <td align="center" bgcolor="#f7f7f7" class="sort1">0</td>
# <td align="center" bgcolor="#e0e0e0" class="sort1">14.8</td>
# <td align="center" bgcolor="#f7f7f7" class="sort1">14.8</td>
# </tr>
# <tr>
# <td align="LEFT" bgcolor="#ffffff" class="sort1"> 9. <a href="/stats/players/15197/Todd_Gurley?LeagueID=">Todd Gurley</a></td>
# <td align="center" bgcolor="#ffffff" class="sort1">LAR</td>
# <td align="center" bgcolor="#ffffff" class="sort1">1</td>
# <td align="center" bgcolor="#ffffff" class="sort1">11</td>
# <td align="center" bgcolor="#ffffff" class="sort1">68</td>
# <td align="center" bgcolor="#ffffff" class="sort1">0</td>
# <td align="center" bgcolor="#ffffff" class="sort1">7</td>
# <td align="center" bgcolor="#ffffff" class="sort1">6</td>
# <td align="center" bgcolor="#ffffff" class="sort1">68</td>
# <td align="center" bgcolor="#ffffff" class="sort1">0</td>
# <td align="center" bgcolor="#e0e0e0" class="sort1">13.6</td>
# <td align="center" bgcolor="#ffffff" class="sort1">13.6</td>
# </tr>
# <tr>
# <td align="LEFT" bgcolor="#f7f7f7" class="sort1"> 10. <a href="/stats/players/15112/Cameron_Artis-Payne?LeagueID=">Cameron Artis-Payne</a></td>
# <td align="center" bgcolor="#f7f7f7" class="sort1">CAR</td>
# <td align="center" bgcolor="#f7f7f7" class="sort1">1</td>
# <td align="center" bgcolor="#f7f7f7" class="sort1">7</td>
# <td align="center" bgcolor="#f7f7f7" class="sort1">68</td>
# <td align="center" bgcolor="#f7f7f7" class="sort1">1</td>
# <td align="center" bgcolor="#f7f7f7" class="sort1">0</td>
# <td align="center" bgcolor="#f7f7f7" class="sort1">0</td>
# <td align="center" bgcolor="#f7f7f7" class="sort1">0</td>
# <td align="center" bgcolor="#f7f7f7" class="sort1">0</td>
# <td align="center" bgcolor="#e0e0e0" class="sort1">12.8</td>
# <td align="center" bgcolor="#f7f7f7" class="sort1">12.8</td>
# </tr>
# <tr>
# <td align="LEFT" bgcolor="#ffffff" class="sort1"> 11. <a href="/stats/players/15253/Ty_Montgomery?LeagueID=">Ty Montgomery</a></td>
# <td align="center" bgcolor="#ffffff" class="sort1">GB</td>
# <td align="center" bgcolor="#ffffff" class="sort1">1</td>
# <td align="center" bgcolor="#ffffff" class="sort1">6</td>
# <td align="center" bgcolor="#ffffff" class="sort1">54</td>
# <td align="center" bgcolor="#ffffff" class="sort1">1</td>
# <td align="center" bgcolor="#ffffff" class="sort1">2</td>
# <td align="center" bgcolor="#ffffff" class="sort1">2</td>
# <td align="center" bgcolor="#ffffff" class="sort1">14</td>
# <td align="center" bgcolor="#ffffff" class="sort1">0</td>
# <td align="center" bgcolor="#e0e0e0" class="sort1">12.8</td>
# <td align="center" bgcolor="#ffffff" class="sort1">12.8</td>
# </tr>
# <tr>
# <td align="LEFT" bgcolor="#f7f7f7" class="sort1"> 12. <a href="/stats/players/13295/Latavius_Murray?LeagueID=">Latavius Murray</a></td>
# <td align="center" bgcolor="#f7f7f7" class="sort1">MIN</td>
# <td align="center" bgcolor="#f7f7f7" class="sort1">1</td>
# <td align="center" bgcolor="#f7f7f7" class="sort1">17</td>
# <td align="center" bgcolor="#f7f7f7" class="sort1">68</td>
# <td align="center" bgcolor="#f7f7f7" class="sort1">1</td>
# <td align="center" bgcolor="#f7f7f7" class="sort1">0</td>
# <td align="center" bgcolor="#f7f7f7" class="sort1">0</td>
# <td align="center" bgcolor="#f7f7f7" class="sort1">0</td>
# <td align="center" bgcolor="#f7f7f7" class="sort1">0</td>
# <td align="center" bgcolor="#e0e0e0" class="sort1">12.8</td>
# <td align="center" bgcolor="#f7f7f7" class="sort1">12.8</td>
# </tr>
# <tr>
# <td align="LEFT" bgcolor="#ffffff" class="sort1"> 13. <a href="/stats/players/13054/Rex_Burkhead?LeagueID=">Rex Burkhead</a></td>
# <td align="center" bgcolor="#ffffff" class="sort1">NE</td>
# <td align="center" bgcolor="#ffffff" class="sort1">1</td>
# <td align="center" bgcolor="#ffffff" class="sort1">10</td>
# <td align="center" bgcolor="#ffffff" class="sort1">36</td>
# <td align="center" bgcolor="#ffffff" class="sort1">0</td>
# <td align="center" bgcolor="#ffffff" class="sort1">3</td>
# <td align="center" bgcolor="#ffffff" class="sort1">3</td>
# <td align="center" bgcolor="#ffffff" class="sort1">27</td>
# <td align="center" bgcolor="#ffffff" class="sort1">1</td>
# <td align="center" bgcolor="#e0e0e0" class="sort1">12.3</td>
# <td align="center" bgcolor="#ffffff" class="sort1">12.3</td>
# </tr>
# <tr>
# <td align="LEFT" bgcolor="#f7f7f7" class="sort1"> 14. <a href="/stats/players/14903/Matt_Breida?LeagueID=">Matt Breida</a></td>
# <td align="center" bgcolor="#f7f7f7" class="sort1">SF</td>
# <td align="center" bgcolor="#f7f7f7" class="sort1">1</td>
# <td align="center" bgcolor="#f7f7f7" class="sort1">9</td>
# <td align="center" bgcolor="#f7f7f7" class="sort1">55</td>
# <td align="center" bgcolor="#f7f7f7" class="sort1">1</td>
# <td align="center" bgcolor="#f7f7f7" class="sort1">2</td>
# <td align="center" bgcolor="#f7f7f7" class="sort1">1</td>
# <td align="center" bgcolor="#f7f7f7" class="sort1">3</td>
# <td align="center" bgcolor="#f7f7f7" class="sort1">0</td>
# <td align="center" bgcolor="#e0e0e0" class="sort1">11.8</td>
# <td align="center" bgcolor="#f7f7f7" class="sort1">11.8</td>
# </tr>
# <tr>
# <td align="LEFT" bgcolor="#ffffff" class="sort1"> 15. <a href="/stats/players/14597/Corey_Grant?LeagueID=">Corey Grant</a></td>
# <td align="center" bgcolor="#ffffff" class="sort1">JAC</td>
# <td align="center" bgcolor="#ffffff" class="sort1">1</td>
# <td align="center" bgcolor="#ffffff" class="sort1">1</td>
# <td align="center" bgcolor="#ffffff" class="sort1">56</td>
# <td align="center" bgcolor="#ffffff" class="sort1">1</td>
# <td align="center" bgcolor="#ffffff" class="sort1">0</td>
# <td align="center" bgcolor="#ffffff" class="sort1">0</td>
# <td align="center" bgcolor="#ffffff" class="sort1">0</td>
# <td align="center" bgcolor="#ffffff" class="sort1">0</td>
# <td align="center" bgcolor="#e0e0e0" class="sort1">11.6</td>
# <td align="center" bgcolor="#ffffff" class="sort1">11.6</td>
# </tr>
# <tr>
# <td align="LEFT" bgcolor="#f7f7f7" class="sort1"> 16. <a href="/stats/players/15100/Ameer_Abdullah?LeagueID=">Ameer Abdullah</a></td>
# <td align="center" bgcolor="#f7f7f7" class="sort1">DET</td>
# <td align="center" bgcolor="#f7f7f7" class="sort1">1</td>
# <td align="center" bgcolor="#f7f7f7" class="sort1">11</td>
# <td align="center" bgcolor="#f7f7f7" class="sort1">52</td>
# <td align="center" bgcolor="#f7f7f7" class="sort1">1</td>
# <td align="center" bgcolor="#f7f7f7" class="sort1">2</td>
# <td align="center" bgcolor="#f7f7f7" class="sort1">1</td>
# <td align="center" bgcolor="#f7f7f7" class="sort1">3</td>
# <td align="center" bgcolor="#f7f7f7" class="sort1">0</td>
# <td align="center" bgcolor="#e0e0e0" class="sort1">11.5</td>
# <td align="center" bgcolor="#f7f7f7" class="sort1">11.5</td>
# </tr>
# <tr>
# <td align="LEFT" bgcolor="#ffffff" class="sort1"> 17. <a href="/stats/players/12003/Dion_Lewis?LeagueID=">Dion Lewis</a></td>
# <td align="center" bgcolor="#ffffff" class="sort1">NE</td>
# <td align="center" bgcolor="#ffffff" class="sort1">1</td>
# <td align="center" bgcolor="#ffffff" class="sort1">14</td>
# <td align="center" bgcolor="#ffffff" class="sort1">55</td>
# <td align="center" bgcolor="#ffffff" class="sort1">1</td>
# <td align="center" bgcolor="#ffffff" class="sort1">0</td>
# <td align="center" bgcolor="#ffffff" class="sort1">0</td>
# <td align="center" bgcolor="#ffffff" class="sort1">0</td>
# <td align="center" bgcolor="#ffffff" class="sort1">0</td>
# <td align="center" bgcolor="#e0e0e0" class="sort1">11.5</td>
# <td align="center" bgcolor="#ffffff" class="sort1">11.5</td>
# </tr>
# <tr>
# <td align="LEFT" bgcolor="#f7f7f7" class="sort1"> 18. <a href="/stats/players/13029/Le'Veon_Bell?LeagueID=">Le'Veon Bell</a></td>
# <td align="center" bgcolor="#f7f7f7" class="sort1">PIT</td>
# <td align="center" bgcolor="#f7f7f7" class="sort1">1</td>
# <td align="center" bgcolor="#f7f7f7" class="sort1">26</td>
# <td align="center" bgcolor="#f7f7f7" class="sort1">80</td>
# <td align="center" bgcolor="#f7f7f7" class="sort1">0</td>
# <td align="center" bgcolor="#f7f7f7" class="sort1">6</td>
# <td align="center" bgcolor="#f7f7f7" class="sort1">5</td>
# <td align="center" bgcolor="#f7f7f7" class="sort1">32</td>
# <td align="center" bgcolor="#f7f7f7" class="sort1">0</td>
# <td align="center" bgcolor="#e0e0e0" class="sort1">11.2</td>
# <td align="center" bgcolor="#f7f7f7" class="sort1">11.2</td>
# </tr>
# <tr>
# <td align="LEFT" bgcolor="#ffffff" class="sort1"> 19. <a href="/stats/players/2967/Jonathan_Stewart?LeagueID=">Jonathan Stewart</a></td>
# <td align="center" bgcolor="#ffffff" class="sort1">CAR</td>
# <td align="center" bgcolor="#ffffff" class="sort1">1</td>
# <td align="center" bgcolor="#ffffff" class="sort1">17</td>
# <td align="center" bgcolor="#ffffff" class="sort1">110</td>
# <td align="center" bgcolor="#ffffff" class="sort1">0</td>
# <td align="center" bgcolor="#ffffff" class="sort1">0</td>
# <td align="center" bgcolor="#ffffff" class="sort1">0</td>
# <td align="center" bgcolor="#ffffff" class="sort1">0</td>
# <td align="center" bgcolor="#ffffff" class="sort1">0</td>
# <td align="center" bgcolor="#e0e0e0" class="sort1">11.0</td>
# <td align="center" bgcolor="#ffffff" class="sort1">11.0</td>
# </tr>
# <tr>
# <td align="LEFT" bgcolor="#f7f7f7" class="sort1"> 20. <a href="/stats/players/14935/Trey_Edmunds?LeagueID=">Trey Edmunds</a></td>
# <td align="center" bgcolor="#f7f7f7" class="sort1">NO</td>
# <td align="center" bgcolor="#f7f7f7" class="sort1">1</td>
# <td align="center" bgcolor="#f7f7f7" class="sort1">9</td>
# <td align="center" bgcolor="#f7f7f7" class="sort1">48</td>
# <td align="center" bgcolor="#f7f7f7" class="sort1">1</td>
# <td align="center" bgcolor="#f7f7f7" class="sort1">0</td>
# <td align="center" bgcolor="#f7f7f7" class="sort1">0</td>
# <td align="center" bgcolor="#f7f7f7" class="sort1">0</td>
# <td align="center" bgcolor="#f7f7f7" class="sort1">0</td>
# <td align="center" bgcolor="#e0e0e0" class="sort1">10.8</td>
# <td align="center" bgcolor="#f7f7f7" class="sort1">10.8</td>
# </tr>
# <tr>
# <td align="LEFT" bgcolor="#ffffff" class="sort1"> 21. <a href="/stats/players/13334/Theo_Riddick?LeagueID=">Theo Riddick</a></td>
# <td align="center" bgcolor="#ffffff" class="sort1">DET</td>
# <td align="center" bgcolor="#ffffff" class="sort1">1</td>
# <td align="center" bgcolor="#ffffff" class="sort1">4</td>
# <td align="center" bgcolor="#ffffff" class="sort1">35</td>
# <td align="center" bgcolor="#ffffff" class="sort1">0</td>
# <td align="center" bgcolor="#ffffff" class="sort1">3</td>
# <td align="center" bgcolor="#ffffff" class="sort1">3</td>
# <td align="center" bgcolor="#ffffff" class="sort1">12</td>
# <td align="center" bgcolor="#ffffff" class="sort1">1</td>
# <td align="center" bgcolor="#e0e0e0" class="sort1">10.7</td>
# <td align="center" bgcolor="#ffffff" class="sort1">10.7</td>
# </tr>
# <tr>
# <td align="LEFT" bgcolor="#f7f7f7" class="sort1"> 22. <a href="/stats/players/14212/Carlos_Hyde?LeagueID=">Carlos Hyde</a></td>
# <td align="center" bgcolor="#f7f7f7" class="sort1">SF</td>
# <td align="center" bgcolor="#f7f7f7" class="sort1">1</td>
# <td align="center" bgcolor="#f7f7f7" class="sort1">17</td>
# <td align="center" bgcolor="#f7f7f7" class="sort1">98</td>
# <td align="center" bgcolor="#f7f7f7" class="sort1">0</td>
# <td align="center" bgcolor="#f7f7f7" class="sort1">3</td>
# <td align="center" bgcolor="#f7f7f7" class="sort1">2</td>
# <td align="center" bgcolor="#f7f7f7" class="sort1">6</td>
# <td align="center" bgcolor="#f7f7f7" class="sort1">0</td>
# <td align="center" bgcolor="#e0e0e0" class="sort1">10.4</td>
# <td align="center" bgcolor="#f7f7f7" class="sort1">10.4</td>
# </tr>
# <tr>
# <td align="LEFT" bgcolor="#ffffff" class="sort1"> 23. <a href="/stats/players/15961/Joe_Mixon?LeagueID=">Joe Mixon</a></td>
# <td align="center" bgcolor="#ffffff" class="sort1">CIN</td>
# <td align="center" bgcolor="#ffffff" class="sort1">1</td>
# <td align="center" bgcolor="#ffffff" class="sort1">9</td>
# <td align="center" bgcolor="#ffffff" class="sort1">37</td>
# <td align="center" bgcolor="#ffffff" class="sort1">1</td>
# <td align="center" bgcolor="#ffffff" class="sort1">3</td>
# <td align="center" bgcolor="#ffffff" class="sort1">1</td>
# <td align="center" bgcolor="#ffffff" class="sort1">3</td>
# <td align="center" bgcolor="#ffffff" class="sort1">0</td>
# <td align="center" bgcolor="#e0e0e0" class="sort1">10.0</td>
# <td align="center" bgcolor="#ffffff" class="sort1">10.0</td>
# </tr>
# <tr>
# <td align="LEFT" bgcolor="#f7f7f7" class="sort1"> 24. <a href="/stats/players/13103/Andre_Ellington?LeagueID=">Andre Ellington</a></td>
# <td align="center" bgcolor="#f7f7f7" class="sort1">ARI</td>
# <td align="center" bgcolor="#f7f7f7" class="sort1">1</td>
# <td align="center" bgcolor="#f7f7f7" class="sort1">2</td>
# <td align="center" bgcolor="#f7f7f7" class="sort1">4</td>
# <td align="center" bgcolor="#f7f7f7" class="sort1">1</td>
# <td align="center" bgcolor="#f7f7f7" class="sort1">6</td>
# <td align="center" bgcolor="#f7f7f7" class="sort1">3</td>
# <td align="center" bgcolor="#f7f7f7" class="sort1">26</td>
# <td align="center" bgcolor="#f7f7f7" class="sort1">0</td>
# <td align="center" bgcolor="#e0e0e0" class="sort1">9.0</td>
# <td align="center" bgcolor="#f7f7f7" class="sort1">9.0</td>
# </tr>
# <tr>
# <td align="LEFT" bgcolor="#ffffff" class="sort1"> 25. <a href="/stats/players/14314/Charles_Sims?LeagueID=">Charles Sims</a></td>
# <td align="center" bgcolor="#ffffff" class="sort1">TB</td>
# <td align="center" bgcolor="#ffffff" class="sort1">1</td>
# <td align="center" bgcolor="#ffffff" class="sort1">3</td>
# <td align="center" bgcolor="#ffffff" class="sort1">20</td>
# <td align="center" bgcolor="#ffffff" class="sort1">0</td>
# <td align="center" bgcolor="#ffffff" class="sort1">4</td>
# <td align="center" bgcolor="#ffffff" class="sort1">3</td>
# <td align="center" bgcolor="#ffffff" class="sort1">10</td>
# <td align="center" bgcolor="#ffffff" class="sort1">1</td>
# <td align="center" bgcolor="#e0e0e0" class="sort1">9.0</td>
# <td align="center" bgcolor="#ffffff" class="sort1">9.0</td>
# </tr>
# <tr>
# <td align="LEFT" bgcolor="#f7f7f7" class="sort1"> 26. <a href="/stats/players/14446/Orleans_Darkwa?LeagueID=">Orleans Darkwa</a></td>
# <td align="center" bgcolor="#f7f7f7" class="sort1">NYG</td>
# <td align="center" bgcolor="#f7f7f7" class="sort1">1</td>
# <td align="center" bgcolor="#f7f7f7" class="sort1">14</td>
# <td align="center" bgcolor="#f7f7f7" class="sort1">70</td>
# <td align="center" bgcolor="#f7f7f7" class="sort1">0</td>
# <td align="center" bgcolor="#f7f7f7" class="sort1">2</td>
# <td align="center" bgcolor="#f7f7f7" class="sort1">2</td>
# <td align="center" bgcolor="#f7f7f7" class="sort1">18</td>
# <td align="center" bgcolor="#f7f7f7" class="sort1">0</td>
# <td align="center" bgcolor="#e0e0e0" class="sort1">8.8</td>
# <td align="center" bgcolor="#f7f7f7" class="sort1">8.8</td>
# </tr>
# <tr>
# <td align="LEFT" bgcolor="#ffffff" class="sort1"> 27. <a href="/stats/players/15221/Duke_Johnson?LeagueID=">Duke Johnson</a></td>
# <td align="center" bgcolor="#ffffff" class="sort1">CLE</td>
# <td align="center" bgcolor="#ffffff" class="sort1">1</td>
# <td align="center" bgcolor="#ffffff" class="sort1">10</td>
# <td align="center" bgcolor="#ffffff" class="sort1">54</td>
# <td align="center" bgcolor="#ffffff" class="sort1">0</td>
# <td align="center" bgcolor="#ffffff" class="sort1">6</td>
# <td align="center" bgcolor="#ffffff" class="sort1">6</td>
# <td align="center" bgcolor="#ffffff" class="sort1">34</td>
# <td align="center" bgcolor="#ffffff" class="sort1">0</td>
# <td align="center" bgcolor="#e0e0e0" class="sort1">8.8</td>
# <td align="center" bgcolor="#ffffff" class="sort1">8.8</td>
# </tr>
# <tr>
# <td align="LEFT" bgcolor="#f7f7f7" class="sort1"> 28. <a href="/stats/players/14358/James_White?LeagueID=">James White</a></td>
# <td align="center" bgcolor="#f7f7f7" class="sort1">NE</td>
# <td align="center" bgcolor="#f7f7f7" class="sort1">1</td>
# <td align="center" bgcolor="#f7f7f7" class="sort1">2</td>
# <td align="center" bgcolor="#f7f7f7" class="sort1">7</td>
# <td align="center" bgcolor="#f7f7f7" class="sort1">0</td>
# <td align="center" bgcolor="#f7f7f7" class="sort1">3</td>
# <td align="center" bgcolor="#f7f7f7" class="sort1">3</td>
# <td align="center" bgcolor="#f7f7f7" class="sort1">11</td>
# <td align="center" bgcolor="#f7f7f7" class="sort1">1</td>
# <td align="center" bgcolor="#e0e0e0" class="sort1">7.8</td>
# <td align="center" bgcolor="#f7f7f7" class="sort1">7.8</td>
# </tr>
# <tr>
# <td align="LEFT" bgcolor="#ffffff" class="sort1"> 29. <a href="/stats/players/12371/Lamar_Miller?LeagueID=">Lamar Miller</a></td>
# <td align="center" bgcolor="#ffffff" class="sort1">HOU</td>
# <td align="center" bgcolor="#ffffff" class="sort1">1</td>
# <td align="center" bgcolor="#ffffff" class="sort1">11</td>
# <td align="center" bgcolor="#ffffff" class="sort1">60</td>
# <td align="center" bgcolor="#ffffff" class="sort1">0</td>
# <td align="center" bgcolor="#ffffff" class="sort1">1</td>
# <td align="center" bgcolor="#ffffff" class="sort1">1</td>
# <td align="center" bgcolor="#ffffff" class="sort1">14</td>
# <td align="center" bgcolor="#ffffff" class="sort1">0</td>
# <td align="center" bgcolor="#e0e0e0" class="sort1">7.4</td>
# <td align="center" bgcolor="#ffffff" class="sort1">7.4</td>
# </tr>
# <tr>
# <td align="LEFT" bgcolor="#f7f7f7" class="sort1"> 30. <a href="/stats/players/16038/Jamaal_Williams?LeagueID=">Jamaal Williams</a></td>
# <td align="center" bgcolor="#f7f7f7" class="sort1">GB</td>
# <td align="center" bgcolor="#f7f7f7" class="sort1">1</td>
# <td align="center" bgcolor="#f7f7f7" class="sort1">20</td>
# <td align="center" bgcolor="#f7f7f7" class="sort1">67</td>
# <td align="center" bgcolor="#f7f7f7" class="sort1">0</td>
# <td align="center" bgcolor="#f7f7f7" class="sort1">1</td>
# <td align="center" bgcolor="#f7f7f7" class="sort1">1</td>
# <td align="center" bgcolor="#f7f7f7" class="sort1">7</td>
# <td align="center" bgcolor="#f7f7f7" class="sort1">0</td>
# <td align="center" bgcolor="#e0e0e0" class="sort1">7.4</td>
# <td align="center" bgcolor="#f7f7f7" class="sort1">7.4</td>
# </tr>
# <tr>
# <td align="LEFT" bgcolor="#ffffff" class="sort1"> 31. <a href="/stats/players/13403/Chris_Thompson?LeagueID=">Chris Thompson</a></td>
# <td align="center" bgcolor="#ffffff" class="sort1">WAS</td>
# <td align="center" bgcolor="#ffffff" class="sort1">1</td>
# <td align="center" bgcolor="#ffffff" class="sort1">9</td>
# <td align="center" bgcolor="#ffffff" class="sort1">26</td>
# <td align="center" bgcolor="#ffffff" class="sort1">0</td>
# <td align="center" bgcolor="#ffffff" class="sort1">7</td>
# <td align="center" bgcolor="#ffffff" class="sort1">3</td>
# <td align="center" bgcolor="#ffffff" class="sort1">41</td>
# <td align="center" bgcolor="#ffffff" class="sort1">0</td>
# <td align="center" bgcolor="#e0e0e0" class="sort1">6.7</td>
# <td align="center" bgcolor="#ffffff" class="sort1">6.7</td>
# </tr>
# <tr>
# <td align="LEFT" bgcolor="#f7f7f7" class="sort1"> 32. <a href="/stats/players/2491/Frank_Gore?LeagueID=">Frank Gore</a></td>
# <td align="center" bgcolor="#f7f7f7" class="sort1">IND</td>
# <td align="center" bgcolor="#f7f7f7" class="sort1">1</td>
# <td align="center" bgcolor="#f7f7f7" class="sort1">17</td>
# <td align="center" bgcolor="#f7f7f7" class="sort1">54</td>
# <td align="center" bgcolor="#f7f7f7" class="sort1">0</td>
# <td align="center" bgcolor="#f7f7f7" class="sort1">1</td>
# <td align="center" bgcolor="#f7f7f7" class="sort1">1</td>
# <td align="center" bgcolor="#f7f7f7" class="sort1">7</td>
# <td align="center" bgcolor="#f7f7f7" class="sort1">0</td>
# <td align="center" bgcolor="#e0e0e0" class="sort1">6.1</td>
# <td align="center" bgcolor="#f7f7f7" class="sort1">6.1</td>
# </tr>
# <tr>
# <td align="LEFT" bgcolor="#ffffff" class="sort1"> 33. <a href="/stats/players/11053/LeSean_McCoy?LeagueID=">LeSean McCoy</a></td>
# <td align="center" bgcolor="#ffffff" class="sort1">BUF</td>
# <td align="center" bgcolor="#ffffff" class="sort1">1</td>
# <td align="center" bgcolor="#ffffff" class="sort1">8</td>
# <td align="center" bgcolor="#ffffff" class="sort1">49</td>
# <td align="center" bgcolor="#ffffff" class="sort1">0</td>
# <td align="center" bgcolor="#ffffff" class="sort1">5</td>
# ...
# </tr>
# <tr>
# <td align="LEFT" bgcolor="#ffffff" class="sort1"> 29. <a href="/stats/players/14273/Troy_Niklas?LeagueID=">Troy Niklas</a></td>
# <td align="center" bgcolor="#ffffff" class="sort1">ARI</td>
# <td align="center" bgcolor="#ffffff" class="sort1">1</td>
# <td align="center" bgcolor="#ffffff" class="sort1">2</td>
# <td align="center" bgcolor="#ffffff" class="sort1">2</td>
# <td align="center" bgcolor="#ffffff" class="sort1">22</td>
# <td align="center" bgcolor="#ffffff" class="sort1">0</td>
# <td align="center" bgcolor="#e0e0e0" class="sort1">2.2</td>
# <td align="center" bgcolor="#ffffff" class="sort1">2.2</td>
# </tr>
# <tr>
# <td align="LEFT" bgcolor="#f7f7f7" class="sort1"> 30. <a href="/stats/players/14695/Daniel_Brown?LeagueID=">Daniel Brown</a></td>
# <td align="center" bgcolor="#f7f7f7" class="sort1">CHI</td>
# <td align="center" bgcolor="#f7f7f7" class="sort1">1</td>
# <td align="center" bgcolor="#f7f7f7" class="sort1">3</td>
# <td align="center" bgcolor="#f7f7f7" class="sort1">2</td>
# <td align="center" bgcolor="#f7f7f7" class="sort1">20</td>
# <td align="center" bgcolor="#f7f7f7" class="sort1">0</td>
# <td align="center" bgcolor="#e0e0e0" class="sort1">2.0</td>
# <td align="center" bgcolor="#f7f7f7" class="sort1">2.0</td>
# </tr>
# <tr>
# <td align="LEFT" bgcolor="#ffffff" class="sort1"> 31. <a href="/stats/players/15862/Evan_Engram?LeagueID=">Evan Engram</a></td>
# <td align="center" bgcolor="#ffffff" class="sort1">NYG</td>
# <td align="center" bgcolor="#ffffff" class="sort1">1</td>
# <td align="center" bgcolor="#ffffff" class="sort1">7</td>
# <td align="center" bgcolor="#ffffff" class="sort1">3</td>
# <td align="center" bgcolor="#ffffff" class="sort1">18</td>
# <td align="center" bgcolor="#ffffff" class="sort1">0</td>
# <td align="center" bgcolor="#e0e0e0" class="sort1">1.8</td>
# <td align="center" bgcolor="#ffffff" class="sort1">1.8</td>
# </tr>
# <tr>
# <td align="LEFT" bgcolor="#f7f7f7" class="sort1"> 32. <a href="/stats/players/15268/Nick_O'Leary?LeagueID=">Nick O'Leary</a></td>
# <td align="center" bgcolor="#f7f7f7" class="sort1">BUF</td>
# <td align="center" bgcolor="#f7f7f7" class="sort1">1</td>
# <td align="center" bgcolor="#f7f7f7" class="sort1">2</td>
# <td align="center" bgcolor="#f7f7f7" class="sort1">2</td>
# <td align="center" bgcolor="#f7f7f7" class="sort1">18</td>
# <td align="center" bgcolor="#f7f7f7" class="sort1">0</td>
# <td align="center" bgcolor="#e0e0e0" class="sort1">1.8</td>
# <td align="center" bgcolor="#f7f7f7" class="sort1">1.8</td>
# </tr>
# <tr>
# <td align="LEFT" bgcolor="#ffffff" class="sort1"> 33. <a href="/stats/players/12058/Virgil_Green?LeagueID=">Virgil Green</a></td>
# <td align="center" bgcolor="#ffffff" class="sort1">DEN</td>
# <td align="center" bgcolor="#ffffff" class="sort1">1</td>
# <td align="center" bgcolor="#ffffff" class="sort1">3</td>
# <td align="center" bgcolor="#ffffff" class="sort1">1</td>
# <td align="center" bgcolor="#ffffff" class="sort1">16</td>
# <td align="center" bgcolor="#ffffff" class="sort1">0</td>
# <td align="center" bgcolor="#e0e0e0" class="sort1">1.6</td>
# <td align="center" bgcolor="#ffffff" class="sort1">1.6</td>
# </tr>
# <tr>
# <td align="LEFT" bgcolor="#f7f7f7" class="sort1"> 34. <a href="/stats/players/12009/Niles_Paul?LeagueID=">Niles Paul</a></td>
# <td align="center" bgcolor="#f7f7f7" class="sort1">WAS</td>
# <td align="center" bgcolor="#f7f7f7" class="sort1">1</td>
# <td align="center" bgcolor="#f7f7f7" class="sort1">5</td>
# <td align="center" bgcolor="#f7f7f7" class="sort1">3</td>
# <td align="center" bgcolor="#f7f7f7" class="sort1">16</td>
# <td align="center" bgcolor="#f7f7f7" class="sort1">0</td>
# <td align="center" bgcolor="#e0e0e0" class="sort1">1.6</td>
# <td align="center" bgcolor="#f7f7f7" class="sort1">1.6</td>
# </tr>
# <tr>
# <td align="LEFT" bgcolor="#ffffff" class="sort1"> 35. <a href="/stats/players/11480/Ed_Dickson?LeagueID=">Ed Dickson</a></td>
# <td align="center" bgcolor="#ffffff" class="sort1">CAR</td>
# <td align="center" bgcolor="#ffffff" class="sort1">1</td>
# <td align="center" bgcolor="#ffffff" class="sort1">3</td>
# <td align="center" bgcolor="#ffffff" class="sort1">1</td>
# <td align="center" bgcolor="#ffffff" class="sort1">15</td>
# <td align="center" bgcolor="#ffffff" class="sort1">0</td>
# <td align="center" bgcolor="#e0e0e0" class="sort1">1.5</td>
# <td align="center" bgcolor="#ffffff" class="sort1">1.5</td>
# </tr>
# <tr>
# <td align="LEFT" bgcolor="#f7f7f7" class="sort1"> 36. <a href="/stats/players/15929/George_Kittle?LeagueID=">George Kittle</a></td>
# <td align="center" bgcolor="#f7f7f7" class="sort1">SF</td>
# <td align="center" bgcolor="#f7f7f7" class="sort1">1</td>
# <td align="center" bgcolor="#f7f7f7" class="sort1">2</td>
# <td align="center" bgcolor="#f7f7f7" class="sort1">1</td>
# <td align="center" bgcolor="#f7f7f7" class="sort1">14</td>
# <td align="center" bgcolor="#f7f7f7" class="sort1">0</td>
# <td align="center" bgcolor="#e0e0e0" class="sort1">1.4</td>
# <td align="center" bgcolor="#f7f7f7" class="sort1">1.4</td>
# </tr>
# <tr>
# <td align="LEFT" bgcolor="#ffffff" class="sort1"> 37. <a href="/stats/players/11431/Jermaine_Gresham?LeagueID=">Jermaine Gresham</a></td>
# <td align="center" bgcolor="#ffffff" class="sort1">ARI</td>
# <td align="center" bgcolor="#ffffff" class="sort1">1</td>
# <td align="center" bgcolor="#ffffff" class="sort1">3</td>
# <td align="center" bgcolor="#ffffff" class="sort1">2</td>
# <td align="center" bgcolor="#ffffff" class="sort1">13</td>
# <td align="center" bgcolor="#ffffff" class="sort1">0</td>
# <td align="center" bgcolor="#e0e0e0" class="sort1">1.3</td>
# <td align="center" bgcolor="#ffffff" class="sort1">1.3</td>
# </tr>
# <tr>
# <td align="LEFT" bgcolor="#f7f7f7" class="sort1"> 38. <a href="/stats/players/12013/Lee_Smith?LeagueID=">Lee Smith</a></td>
# <td align="center" bgcolor="#f7f7f7" class="sort1">OAK</td>
# <td align="center" bgcolor="#f7f7f7" class="sort1">1</td>
# <td align="center" bgcolor="#f7f7f7" class="sort1">1</td>
# <td align="center" bgcolor="#f7f7f7" class="sort1">1</td>
# <td align="center" bgcolor="#f7f7f7" class="sort1">12</td>
# <td align="center" bgcolor="#f7f7f7" class="sort1">0</td>
# <td align="center" bgcolor="#e0e0e0" class="sort1">1.2</td>
# <td align="center" bgcolor="#f7f7f7" class="sort1">1.2</td>
# </tr>
# <tr>
# <td align="LEFT" bgcolor="#ffffff" class="sort1"> 39. <a href="/stats/players/15349/Maxx_Williams?LeagueID=">Maxx Williams</a></td>
# <td align="center" bgcolor="#ffffff" class="sort1">BAL</td>
# <td align="center" bgcolor="#ffffff" class="sort1">1</td>
# <td align="center" bgcolor="#ffffff" class="sort1">1</td>
# <td align="center" bgcolor="#ffffff" class="sort1">1</td>
# <td align="center" bgcolor="#ffffff" class="sort1">12</td>
# <td align="center" bgcolor="#ffffff" class="sort1">0</td>
# <td align="center" bgcolor="#e0e0e0" class="sort1">1.2</td>
# <td align="center" bgcolor="#ffffff" class="sort1">1.2</td>
# </tr>
# <tr>
# <td align="LEFT" bgcolor="#f7f7f7" class="sort1"> 40. <a href="/stats/players/2612/Marcedes_Lewis?LeagueID=">Marcedes Lewis</a></td>
# <td align="center" bgcolor="#f7f7f7" class="sort1">JAC</td>
# <td align="center" bgcolor="#f7f7f7" class="sort1">1</td>
# <td align="center" bgcolor="#f7f7f7" class="sort1">2</td>
# <td align="center" bgcolor="#f7f7f7" class="sort1">1</td>
# <td align="center" bgcolor="#f7f7f7" class="sort1">10</td>
# <td align="center" bgcolor="#f7f7f7" class="sort1">0</td>
# <td align="center" bgcolor="#e0e0e0" class="sort1">1.0</td>
# <td align="center" bgcolor="#f7f7f7" class="sort1">1.0</td>
# </tr>
# <tr>
# <td align="LEFT" bgcolor="#ffffff" class="sort1"> 41. <a href="/stats/players/2761/Greg_Olsen?LeagueID=">Greg Olsen</a></td>
# <td align="center" bgcolor="#ffffff" class="sort1">CAR</td>
# <td align="center" bgcolor="#ffffff" class="sort1">1</td>
# <td align="center" bgcolor="#ffffff" class="sort1">4</td>
# <td align="center" bgcolor="#ffffff" class="sort1">1</td>
# <td align="center" bgcolor="#ffffff" class="sort1">10</td>
# <td align="center" bgcolor="#ffffff" class="sort1">0</td>
# <td align="center" bgcolor="#e0e0e0" class="sort1">1.0</td>
# <td align="center" bgcolor="#ffffff" class="sort1">1.0</td>
# </tr>
# <tr>
# <td align="LEFT" bgcolor="#f7f7f7" class="sort1"> 42. <a href="/stats/players/15120/Nick_Boyle?LeagueID=">Nick Boyle</a></td>
# <td align="center" bgcolor="#f7f7f7" class="sort1">BAL</td>
# <td align="center" bgcolor="#f7f7f7" class="sort1">1</td>
# <td align="center" bgcolor="#f7f7f7" class="sort1">1</td>
# <td align="center" bgcolor="#f7f7f7" class="sort1">1</td>
# <td align="center" bgcolor="#f7f7f7" class="sort1">9</td>
# <td align="center" bgcolor="#f7f7f7" class="sort1">0</td>
# <td align="center" bgcolor="#e0e0e0" class="sort1">0.9</td>
# <td align="center" bgcolor="#f7f7f7" class="sort1">0.9</td>
# </tr>
# <tr>
# <td align="LEFT" bgcolor="#ffffff" class="sort1"> 43. <a href="/stats/players/12402/Rhett_Ellison?LeagueID=">Rhett Ellison</a></td>
# <td align="center" bgcolor="#ffffff" class="sort1">NYG</td>
# <td align="center" bgcolor="#ffffff" class="sort1">1</td>
# <td align="center" bgcolor="#ffffff" class="sort1">1</td>
# <td align="center" bgcolor="#ffffff" class="sort1">1</td>
# <td align="center" bgcolor="#ffffff" class="sort1">9</td>
# <td align="center" bgcolor="#ffffff" class="sort1">0</td>
# <td align="center" bgcolor="#e0e0e0" class="sort1">0.9</td>
# <td align="center" bgcolor="#ffffff" class="sort1">0.9</td>
# </tr>
# <tr>
# <td align="LEFT" bgcolor="#f7f7f7" class="sort1"> 44. <a href="/stats/players/15865/Gerald_Everett?LeagueID=">Gerald Everett</a></td>
# <td align="center" bgcolor="#f7f7f7" class="sort1">LAR</td>
# <td align="center" bgcolor="#f7f7f7" class="sort1">1</td>
# <td align="center" bgcolor="#f7f7f7" class="sort1">1</td>
# <td align="center" bgcolor="#f7f7f7" class="sort1">1</td>
# <td align="center" bgcolor="#f7f7f7" class="sort1">9</td>
# <td align="center" bgcolor="#f7f7f7" class="sort1">0</td>
# <td align="center" bgcolor="#e0e0e0" class="sort1">0.9</td>
# <td align="center" bgcolor="#f7f7f7" class="sort1">0.9</td>
# </tr>
# <tr>
# <td align="LEFT" bgcolor="#ffffff" class="sort1"> 45. <a href="/stats/players/12309/Coby_Fleener?LeagueID=">Coby Fleener</a></td>
# <td align="center" bgcolor="#ffffff" class="sort1">NO</td>
# <td align="center" bgcolor="#ffffff" class="sort1">1</td>
# <td align="center" bgcolor="#ffffff" class="sort1">2</td>
# <td align="center" bgcolor="#ffffff" class="sort1">1</td>
# <td align="center" bgcolor="#ffffff" class="sort1">8</td>
# <td align="center" bgcolor="#ffffff" class="sort1">0</td>
# <td align="center" bgcolor="#e0e0e0" class="sort1">0.8</td>
# <td align="center" bgcolor="#ffffff" class="sort1">0.8</td>
# </tr>
# <tr>
# <td align="LEFT" bgcolor="#f7f7f7" class="sort1"> 46. <a href="/stats/players/14551/Garrett_Celek?LeagueID=">Garrett Celek</a></td>
# <td align="center" bgcolor="#f7f7f7" class="sort1">SF</td>
# <td align="center" bgcolor="#f7f7f7" class="sort1">1</td>
# <td align="center" bgcolor="#f7f7f7" class="sort1">2</td>
# <td align="center" bgcolor="#f7f7f7" class="sort1">2</td>
# <td align="center" bgcolor="#f7f7f7" class="sort1">7</td>
# <td align="center" bgcolor="#f7f7f7" class="sort1">0</td>
# <td align="center" bgcolor="#e0e0e0" class="sort1">0.7</td>
# <td align="center" bgcolor="#f7f7f7" class="sort1">0.7</td>
# </tr>
# <tr>
# <td align="LEFT" bgcolor="#ffffff" class="sort1"> 47. <a href="/stats/players/15270/James_O'Shaughnessy?LeagueID=">James O'Shaughnessy</a></td>
# <td align="center" bgcolor="#ffffff" class="sort1">JAC</td>
# <td align="center" bgcolor="#ffffff" class="sort1">1</td>
# <td align="center" bgcolor="#ffffff" class="sort1">2</td>
# <td align="center" bgcolor="#ffffff" class="sort1">1</td>
# <td align="center" bgcolor="#ffffff" class="sort1">7</td>
# <td align="center" bgcolor="#ffffff" class="sort1">0</td>
# <td align="center" bgcolor="#e0e0e0" class="sort1">0.7</td>
# <td align="center" bgcolor="#ffffff" class="sort1">0.7</td>
# </tr>
# <tr>
# <td align="LEFT" bgcolor="#f7f7f7" class="sort1"> 48. <a href="/stats/players/14543/Cameron_Brate?LeagueID=">Cameron Brate</a></td>
# <td align="center" bgcolor="#f7f7f7" class="sort1">TB</td>
# <td align="center" bgcolor="#f7f7f7" class="sort1">1</td>
# <td align="center" bgcolor="#f7f7f7" class="sort1">2</td>
# <td align="center" bgcolor="#f7f7f7" class="sort1">1</td>
# <td align="center" bgcolor="#f7f7f7" class="sort1">6</td>
# <td align="center" bgcolor="#f7f7f7" class="sort1">0</td>
# <td align="center" bgcolor="#e0e0e0" class="sort1">0.6</td>
# <td align="center" bgcolor="#f7f7f7" class="sort1">0.6</td>
# </tr>
# <tr>
# <td align="LEFT" bgcolor="#ffffff" class="sort1"> 49. <a href="/stats/players/12338/Dwayne_Allen?LeagueID=">Dwayne Allen</a></td>
# <td align="center" bgcolor="#ffffff" class="sort1">NE</td>
# <td align="center" bgcolor="#ffffff" class="sort1">1</td>
# <td align="center" bgcolor="#ffffff" class="sort1">2</td>
# <td align="center" bgcolor="#ffffff" class="sort1">1</td>
# <td align="center" bgcolor="#ffffff" class="sort1">2</td>
# <td align="center" bgcolor="#ffffff" class="sort1">0</td>
# <td align="center" bgcolor="#e0e0e0" class="sort1">0.2</td>
# <td align="center" bgcolor="#ffffff" class="sort1">0.2</td>
# </tr>
# <tr>
# <td align="LEFT" bgcolor="#f7f7f7" class="sort1"> 50. <a href="/stats/players/11089/Jared_Cook?LeagueID=">Jared Cook</a></td>
# <td align="center" bgcolor="#f7f7f7" class="sort1">OAK</td>
# <td align="center" bgcolor="#f7f7f7" class="sort1">1</td>
# <td align="center" bgcolor="#f7f7f7" class="sort1">5</td>
# <td align="center" bgcolor="#f7f7f7" class="sort1">1</td>
# <td align="center" bgcolor="#f7f7f7" class="sort1">1</td>
# <td align="center" bgcolor="#f7f7f7" class="sort1">0</td>
# <td align="center" bgcolor="#e0e0e0" class="sort1">0.1</td>
# <td align="center" bgcolor="#f7f7f7" class="sort1">0.1</td>
# </tr>
# </table>
# </td>
# </tr>
# </table><br/>
# <div align="center">
# <a href="?Season=2017&amp;GameWeek=12&amp;PosID=40&amp;LeagueID=&amp;order_by=FFPts&amp;sort_order=DESC&amp;cur_page=1">Next Page</a>  | <a href="?Season=2017&amp;GameWeek=12&amp;PosID=40&amp;LeagueID=&amp;order_by=FFPts&amp;sort_order=DESC&amp;cur_page=1">Last Page</a>
# </div>
# <br/>
# </td>
# <td align="center" bgcolor="#f7f7f7" class="adcolumn" valign="top"> <img height="54" src="/common/spacer_whi.gif" width="5"/><br/>
# <!-- SMG_FFToday/160x600_1a/sports/fantasy/NFL.general -->
# <!-- --><div id="usmg_ad_NFL.general_fantasy_sports_160x600_1a">
# <script type="text/javascript">
# googletag.defineSlot('/7103/SMG_FFToday/160x600_1a/sports/fantasy/NFL.general', [160,600], 'usmg_ad_NFL.general_fantasy_sports_160x600_1a').addService(googletag.pubads());
# googletag.enableServices();
# googletag.display('usmg_ad_NFL.general_fantasy_sports_160x600_1a');
# </script>
# </div>
# <!-- SMG_FFToday/160x600_1a/sports/fantasy/NFL.general end -->
# <br/>
# </td>
# </tr>
# </table>
# <!-- End Main Table -->
# <!-- Footer ----------------------->
# <table border="0" cellpadding="3" cellspacing="1" width="990">
# <tr>
# <td valign="top" width="525">
# <div id="globalfooter">
# <ul class="menu">
# <li><a href="/about/index.htm">Company</a> -</li>
# <li><a href="/privacy/index.htm">Privacy Policy</a> -</li>
# <li><a href="/contact/index.htm">Contact</a> -</li>
# <li><a href="/ad/index.htm">Advertise</a> -</li>
# <li><a href="/members/?r=myfftoday">Log In</a> -</li>
# <li><a href="/signup_fftoday.php">Sign Up</a></li>
# </ul>
# <p align="left" id="copyright">Copyright © 1998-2018 FFToday.com. All rights reserved.<br/>
#   FFToday.com is a member of the <a href="http://www.fsta.org/">Fantasy Sports
#   Trade Association</a>.<br/>
#   Partner of <a href="http://www.usatoday.com/sports/index">USA TODAY Sports Digital Properties</a>.</p></div></td>
# <td align="left" class="copyright" nowrap="" valign="top" width="110"><img height="20" src="/common/spacer_whi.gif" width="1"/><br/><a href="http://twitter.com/FF_Today"><img border="0" height="30" src="/common/icn_twitter_follow_30.gif" width="99"/></a></td>
# <td align="left" class="copyright" nowrap="" valign="top" width="355"><img height="20" src="/common/spacer_whi.gif" width="1"/><br/><a href="http://www.facebook.com/fftoday"><img border="0" height="30" src="/common/icn_facebook_find_30.gif" width="99"/></a></td>
# </tr></table>
# <!-- SMG_FFToday/skin/sports/fantasy/NFL.general -->
# <!-- SMG_FFToday/skin/sports/fantasy/NFL.general end -->
# </center>
# </body></html>
# )]

# %%
from collections import defaultdict

def make_dataframes(data=data):
    dataframes = defaultdict(list)
    for tup in data:
        season, week, position, soup = tup        
        df = parse_page_to_dataframe(soup)
        df.columns = FFTODAY['columns'][position]
        df['season'] = season
        df['week'] = week
        dataframes[position].append(df)
    return dataframes
    
dataframes = make_dataframes()

# %%
def save_to_csv(dataframe, key=''):
    # save to CSV
    season_range = str(dataframe.season.min())
    max_season = str(dataframe.season.max())
    if max_season != season_range:
        season_range += "-" + max_season
    file = str.format("data/fftoday_{}_{}.csv", season_range, 'pos'+str(key))
    print("Saving to file", file)
    dataframe.to_csv(file)
    
for key, value in dataframes.items():
    total_len = sum([len(v) for v in value])
    df = pd.concat(value)
    assert len(df) == total_len
    save_to_csv(df, key)
# Out:
# Saving to file data/fftoday_2017_pos20.csv
# Saving to file data/fftoday_2017_pos30.csv
# Saving to file data/fftoday_2017_pos40.csv

# %%
print(dataframes[40])
# Out:
#                        name team  g rec_target rec_rec rec_yd rec_td    fp  \
# 1              Jimmy Graham  SEA  1          9       6     27      2  14.7
# 2             Garrett Celek   SF  1          6       4     67      1  12.7
# 3          Jermaine Gresham  ARI  1          7       5     64      1  12.4
# 4             Austin Hooper  ATL  1          6       6     49      1  10.9
# 5                Eric Ebron  DET  1          3       2     39      1   9.9
# 6                Ed Dickson  CAR  1          5       3     33      1   9.3
# 7               Evan Engram  NYG  1          9       6     31      1   9.1
# 8              Vernon Davis  WAS  1         11       7     76      0   7.6
# 9            Vance McDonald  PIT  1          2       2     16      1   7.6
# 10           Rob Gronkowski   NE  1          7       4     74      0   7.4
# 11             Dwayne Allen   NE  1          2       1     11      1   7.1
# 12             Seth Devalve  CLE  1          6       4     70      0   7.0
# 13            Julius Thomas  MIA  1          5       2      8      1   6.8
# 14             Nick O'Leary  BUF  1          2       1      7      1   6.7
# 15  Austin Seferian-Jenkins  NYJ  1          9       6     67      0   6.7
# 16           Delanie Walker  TEN  1          9       6     63      0   6.3
# 17             David Morgan  MIN  1          1       1      1      1   6.1
# 18             Jason Witten  DAL  1          7       7     59      0   5.9
# 19             Adam Shaheen  CHI  1          2       2     39      0   3.9
# 20        Martellus Bennett   NE  1          3       3     38      0   3.8
# 21             Kyle Rudolph  MIN  1          7       5     37      0   3.7
# 22         Stephen Anderson  HOU  1          3       2     30      0   3.0
# 23           Marcedes Lewis  JAC  1          5       2     29      0   2.9
# 24             Daniel Brown  CHI  1          3       2     23      0   2.3
# 25             Tyler Higbee  LAR  1          4       2     22      0   2.2
# 26             Nick Vannett  SEA  1          2       2     22      0   2.2
# 27              Jonnu Smith  TEN  1          5       2     20      0   2.0
# 28             Charles Clay  BUF  1          3       2     13      0   1.3
# 29            Cameron Brate   TB  1          3       1     10      0   1.0
# 30         C.J. Fiedorowicz  HOU  1          6       2     10      0   1.0
# ..                      ...  ... ..        ...     ...    ...    ...   ...
# 21               Eric Ebron  DET  1          4       4     34      0   3.4
# 22           Austin Traylor  DEN  1          4       1     34      0   3.4
# 23             Seth Devalve  CLE  1          2       2     33      0   3.3
# 24         Demetrius Harris   KC  1          2       2     33      0   3.3
# 25              Jesse James  PIT  1          4       3     32      0   3.2
# 26               Ben Watson  BAL  1          3       3     29      0   2.9
# 27  Austin Seferian-Jenkins  NYJ  1          7       2     27      0   2.7
# 28          Richard Rodgers   GB  1          3       1     25      0   2.5
# 29              Troy Niklas  ARI  1          2       2     22      0   2.2
# 30             Daniel Brown  CHI  1          3       2     20      0   2.0
# 31              Evan Engram  NYG  1          7       3     18      0   1.8
# 32             Nick O'Leary  BUF  1          2       2     18      0   1.8
# 33             Virgil Green  DEN  1          3       1     16      0   1.6
# 34               Niles Paul  WAS  1          5       3     16      0   1.6
# 35               Ed Dickson  CAR  1          3       1     15      0   1.5
# 36            George Kittle   SF  1          2       1     14      0   1.4
# 37         Jermaine Gresham  ARI  1          3       2     13      0   1.3
# 38                Lee Smith  OAK  1          1       1     12      0   1.2
# 39            Maxx Williams  BAL  1          1       1     12      0   1.2
# 40           Marcedes Lewis  JAC  1          2       1     10      0   1.0
# 41               Greg Olsen  CAR  1          4       1     10      0   1.0
# 42               Nick Boyle  BAL  1          1       1      9      0   0.9
# 43            Rhett Ellison  NYG  1          1       1      9      0   0.9
# 44           Gerald Everett  LAR  1          1       1      9      0   0.9
# 45             Coby Fleener   NO  1          2       1      8      0   0.8
# 46            Garrett Celek   SF  1          2       2      7      0   0.7
# 47      James O'Shaughnessy  JAC  1          2       1      7      0   0.7
# 48            Cameron Brate   TB  1          2       1      6      0   0.6
# 49             Dwayne Allen   NE  1          2       1      2      0   0.2
# 50               Jared Cook  OAK  1          5       1      1      0   0.1
#
#      fpg  season  week
# 1   14.7    2017    10
# 2   12.7    2017    10
# 3   12.4    2017    10
# 4   10.9    2017    10
# 5    9.9    2017    10
# 6    9.3    2017    10
# 7    9.1    2017    10
# 8    7.6    2017    10
# 9    7.6    2017    10
# 10   7.4    2017    10
# 11   7.1    2017    10
# 12   7.0    2017    10
# 13   6.8    2017    10
# 14   6.7    2017    10
# 15   6.7    2017    10
# 16   6.3    2017    10
# 17   6.1    2017    10
# 18   5.9    2017    10
# 19   3.9    2017    10
# 20   3.8    2017    10
# 21   3.7    2017    10
# 22   3.0    2017    10
# 23   2.9    2017    10
# 24   2.3    2017    10
# 25   2.2    2017    10
# 26   2.2    2017    10
# 27   2.0    2017    10
# 28   1.3    2017    10
# 29   1.0    2017    10
# 30   1.0    2017    10
# ..   ...     ...   ...
# 21   3.4    2017    12
# 22   3.4    2017    12
# 23   3.3    2017    12
# 24   3.3    2017    12
# 25   3.2    2017    12
# 26   2.9    2017    12
# 27   2.7    2017    12
# 28   2.5    2017    12
# 29   2.2    2017    12
# 30   2.0    2017    12
# 31   1.8    2017    12
# 32   1.8    2017    12
# 33   1.6    2017    12
# 34   1.6    2017    12
# 35   1.5    2017    12
# 36   1.4    2017    12
# 37   1.3    2017    12
# 38   1.2    2017    12
# 39   1.2    2017    12
# 40   1.0    2017    12
# 41   1.0    2017    12
# 42   0.9    2017    12
# 43   0.9    2017    12
# 44   0.9    2017    12
# 45   0.8    2017    12
# 46   0.7    2017    12
# 47   0.7    2017    12
# 48   0.6    2017    12
# 49   0.2    2017    12
# 50   0.1    2017    12
#
# [150 rows x 11 columns]

# %% [markdown]
# ## Example
#     <tr>
#     <td align="LEFT" bgcolor="#ffffff" class="sort1"> 1. <a href="/stats/players/2480/Aaron_Rodgers?LeagueID=">Aaron Rodgers</a></td>
#     <td align="center" bgcolor="#ffffff" class="sort1">GB</td>
#     <td align="center" bgcolor="#ffffff" class="sort1">16</td>
#     <td align="center" bgcolor="#ffffff" class="sort1">401</td>
#     <td align="center" bgcolor="#ffffff" class="sort1">610</td>
#     <td align="center" bgcolor="#ffffff" class="sort1">4,428</td>
#     <td align="center" bgcolor="#ffffff" class="sort1">40</td>
#     <td align="center" bgcolor="#ffffff" class="sort1">7</td>
#     <td align="center" bgcolor="#ffffff" class="sort1">67</td>
#     <td align="center" bgcolor="#ffffff" class="sort1">369</td>
#     <td align="center" bgcolor="#ffffff" class="sort1">4</td>
#     <td align="center" bgcolor="#e0e0e0" class="sort1">442.3</td>
#     <td align="center" bgcolor="#ffffff" class="sort1">27.6</td>
#     </tr>
#     <tr>

# %%
soup = data[0][1]  # Running Back Stats: 2017 Week 10

# http://fftoday.com/stats/players/11882/Mark_Ingram
df = parse_page_to_dataframe(soup)
# Out:
#                    name team  g rush_att rush_yd rush_td rec_target rec_rec  \
# 1           Mark Ingram   NO  1       21     131       3          0       0
# 2        DeMarco Murray  TEN  1       14      42       2          4       4
# 3         Austin Ekeler  LAC  1       10      42       0          5       5
# 4          Alvin Kamara   NO  1       12     106       1          5       5
# 5   Christian McCaffrey  CAR  1        5      23       1          7       3
# 6        Isaiah Crowell  CLE  1       16      90       1          2       1
# 7          Kenyan Drake  MIA  1        7      82       1          2       2
# 8         Tevin Coleman  ATL  1       20      83       1          1       1
# 9           Todd Gurley  LAR  1       11      68       0          7       6
# 10  Cameron Artis-Payne  CAR  1        7      68       1          0       0
# 11        Ty Montgomery   GB  1        6      54       1          2       2
# 12      Latavius Murray  MIN  1       17      68       1          0       0
# 13         Rex Burkhead   NE  1       10      36       0          3       3
# 14          Matt Breida   SF  1        9      55       1          2       1
# 15          Corey Grant  JAC  1        1      56       1          0       0
# 16       Ameer Abdullah  DET  1       11      52       1          2       1
# 17           Dion Lewis   NE  1       14      55       1          0       0
# 18         Le'Veon Bell  PIT  1       26      80       0          6       5
# 19     Jonathan Stewart  CAR  1       17     110       0          0       0
# 20         Trey Edmunds   NO  1        9      48       1          0       0
# 21         Theo Riddick  DET  1        4      35       0          3       3
# 22          Carlos Hyde   SF  1       17      98       0          3       2
# 23            Joe Mixon  CIN  1        9      37       1          3       1
# 24      Andre Ellington  ARI  1        2       4       1          6       3
# 25         Charles Sims   TB  1        3      20       0          4       3
# 26       Orleans Darkwa  NYG  1       14      70       0          2       2
# 27         Duke Johnson  CLE  1       10      54       0          6       6
# 28          James White   NE  1        2       7       0          3       3
# 29         Lamar Miller  HOU  1       11      60       0          1       1
# 30      Jamaal Williams   GB  1       20      67       0          1       1
# 31       Chris Thompson  WAS  1        9      26       0          7       3
# 32           Frank Gore  IND  1       17      54       0          1       1
# 33         LeSean McCoy  BUF  1        8      49       0          5       3
# 34        Samaje Perine  WAS  1        9      35       0          1       1
# 35       Elijah McGuire  NYJ  1        8      22       0          7       4
# 36        C.J. Anderson  DEN  1       10      54       0          1       1
# 37        Jordan Howard  CHI  1       15      54       0          0       0
# 38        Alfred Morris  DAL  1       11      53       0          0       0
# 39        Derrick Henry  TEN  1       11      52       0          3       0
# 40          Doug Martin   TB  1       20      51       0          2       0
# 41          T.J. Yeldon  JAC  1        3      11       0          8       6
# 42      Giovani Bernard  CIN  1        2      10       0          5       5
# 43      Jerick McKinnon  MIN  1       10      32       0          2       2
# 44    Leonard Fournette  JAC  1       17      33       0          4       2
# 45        J.D. McKissic  SEA  1        5      26       0          5       4
# 46        Melvin Gordon  LAC  1       16      27       0          8       5
# 47      Adrian Peterson  ARI  1       21      29       0          2       1
# 48         Thomas Rawls  SEA  1       10      27       0          2       2
# 49      Damien Williams  MIA  1        9      19       0          3       2
# 50       Jamaal Charles  DEN  1        8      38       0          1       0
#
#    rec_yd rec_td    fp   fpg
# 1       0      0  31.1  31.1
# 2      30      1  25.2  25.2
# 3      77      2  23.9  23.9
# 4      32      0  19.8  19.8
# 5      27      1  17.0  17.0
# 6       5      0  15.5  15.5
# 7      10      0  15.2  15.2
# 8       5      0  14.8  14.8
# 9      68      0  13.6  13.6
# 10      0      0  12.8  12.8
# 11     14      0  12.8  12.8
# 12      0      0  12.8  12.8
# 13     27      1  12.3  12.3
# 14      3      0  11.8  11.8
# 15      0      0  11.6  11.6
# 16      3      0  11.5  11.5
# 17      0      0  11.5  11.5
# 18     32      0  11.2  11.2
# 19      0      0  11.0  11.0
# 20      0      0  10.8  10.8
# 21     12      1  10.7  10.7
# 22      6      0  10.4  10.4
# 23      3      0  10.0  10.0
# 24     26      0   9.0   9.0
# 25     10      1   9.0   9.0
# 26     18      0   8.8   8.8
# 27     34      0   8.8   8.8
# 28     11      1   7.8   7.8
# 29     14      0   7.4   7.4
# 30      7      0   7.4   7.4
# 31     41      0   6.7   6.7
# 32      7      0   6.1   6.1
# 33     11      0   6.0   6.0
# 34     25      0   6.0   6.0
# 35     36      0   5.8   5.8
# 36      1      0   5.5   5.5
# 37      0      0   5.4   5.4
# 38      0      0   5.3   5.3
# 39      0      0   5.2   5.2
# 40      0      0   5.1   5.1
# 41     39      0   5.0   5.0
# 42     38      0   4.8   4.8
# 43     15      0   4.7   4.7
# 44     13      0   4.6   4.6
# 45     20      0   4.6   4.6
# 46     15      0   4.2   4.2
# 47     13      0   4.2   4.2
# 48     12      0   3.9   3.9
# 49     20      0   3.9   3.9
# 50      0      0   3.8   3.8

# %% [markdown]
# # Injury

# %% [markdown]
# # Google Trends

# %%
players = {}

for link in soup.find_all(href=re.compile('/stats/players')):
    name = link.text
    if name != "players":
        row = link.findParent().findParent()
        players[name] = [td.text for td in row.find_all('td')]
print(players)
# Out:
# {'Aaron Rodgers': ['\xa01. Aaron Rodgers', 'GB', '16', '401', '610', '4,428', '40', '7', '67', '369', '4', '442.3', '27.6'], 'Drew Brees': ['\xa02. Drew Brees', 'NO', '16', '471', '673', '5,207', '37', '15', '23', '20', '2', '422.4', '26.4'], 'Matt Ryan': ['\xa03. Matt Ryan', 'ATL', '16', '373', '534', '4,944', '38', '7', '35', '117', '0', '410.9', '25.7'], 'Andrew Luck': ['\xa04. Andrew Luck', 'IND', '15', '346', '545', '4,240', '31', '13', '64', '341', '2', '382.1', '25.5'], 'Kirk Cousins': ['\xa05. Kirk Cousins', 'WAS', '16', '406', '606', '4,917', '25', '12', '34', '100', '4', '379.9', '23.7'], 'Philip Rivers': ['\xa06. Philip Rivers', 'SD', '16', '349', '578', '4,390', '33', '21', '14', '35', '0', '355.0', '22.2'], 'Matthew Stafford': ['\xa07. Matthew Stafford', 'DET', '16', '388', '594', '4,327', '24', '10', '37', '207', '2', '345.1', '21.6'], 'Blake Bortles': ['\xa08. Blake Bortles', 'JAC', '16', '368', '625', '3,905', '23', '16', '58', '359', '3', '341.2', '21.3'], 'Dak Prescott': ['\xa09. Dak Prescott', 'DAL', '16', '311', '459', '3,667', '23', '4', '57', '282', '6', '339.6', '21.2'], 'Jameis Winston': ['\xa010. Jameis Winston', 'TB', '16', '345', '568', '4,090', '28', '18', '52', '168', '1', '339.3', '21.2'], 'Russell Wilson': ['\xa011. Russell Wilson', 'SEA', '16', '353', '546', '4,219', '21', '11', '72', '259', '1', '326.9', '20.4'], 'Andy Dalton': ['\xa012. Andy Dalton', 'CIN', '16', '364', '563', '4,206', '18', '8', '46', '184', '4', '324.7', '20.3'], 'Marcus Mariota': ['\xa013. Marcus Mariota', 'TEN', '15', '276', '451', '3,426', '26', '9', '59', '357', '2', '323.0', '21.5'], 'Carson Palmer': ['\xa014. Carson Palmer', 'ARI', '15', '365', '598', '4,237', '26', '14', '14', '38', '0', '319.7', '21.3'], 'Cam Newton': ['\xa015. Cam Newton', 'CAR', '15', '270', '509', '3,509', '19', '14', '90', '359', '5', '317.4', '21.2'], 'Derek Carr': ['\xa016. Derek Carr', 'OAK', '15', '356', '559', '3,933', '28', '6', '38', '69', '0', '315.6', '21.0'], 'Ben Roethlisberger': ['\xa017. Ben Roethlisberger', 'PIT', '14', '328', '509', '3,819', '29', '13', '16', '14', '1', '314.4', '22.5'], 'Joe Flacco': ['\xa018. Joe Flacco', 'BAL', '16', '437', '673', '4,317', '20', '15', '22', '53', '2', '313.2', '19.6'], 'Tyrod Taylor': ['\xa019. Tyrod Taylor', 'BUF', '15', '270', '437', '3,023', '17', '6', '95', '580', '6', '313.2', '20.9'], 'Eli Manning': ['\xa020. Eli Manning', 'NYG', '16', '377', '598', '4,027', '26', '16', '21', '-9', '0', '304.5', '19.0'], 'Tom Brady': ['\xa021. Tom Brady', 'NE', '12', '291', '432', '3,554', '28', '2', '28', '64', '0', '296.1', '24.7'], 'Carson Wentz': ['\xa022. Carson Wentz', 'PHI', '16', '379', '607', '3,782', '16', '14', '46', '150', '2', '280.1', '17.5'], 'Sam Bradford': ['\xa023. Sam Bradford', 'MIN', '15', '395', '552', '3,877', '20', '5', '20', '53', '0', '279.2', '18.6'], 'Alex Smith': ['\xa024. Alex Smith', 'KC', '15', '328', '489', '3,502', '15', '8', '48', '134', '5', '278.5', '18.6'], 'Ryan Tannehill': ['\xa025. Ryan Tannehill', 'MIA', '13', '261', '389', '2,997', '19', '12', '39', '164', '1', '248.3', '19.1'], 'Trevor Siemian': ['\xa026. Trevor Siemian', 'DEN', '14', '289', '486', '3,401', '18', '10', '28', '57', '0', '247.8', '17.7'], 'Colin Kaepernick': ['\xa027. Colin Kaepernick', 'SF', '11', '196', '332', '2,241', '16', '4', '69', '468', '2', '234.9', '21.4'], 'Brock Osweiler': ['\xa028. Brock Osweiler', 'HOU', '15', '301', '510', '2,957', '15', '16', '30', '131', '2', '233.0', '15.5'], 'Ryan Fitzpatrick': ['\xa029. Ryan Fitzpatrick', 'NYJ', '14', '229', '404', '2,709', '12', '17', '33', '130', '0', '196.5', '14.0'], 'Case Keenum': ['\xa030. Case Keenum', 'LAR', '10', '196', '322', '2,201', '9', '11', '20', '51', '1', '157.2', '15.7'], 'Matt Barkley': ['\xa031. Matt Barkley', 'CHI', '7', '129', '216', '1,611', '8', '14', '7', '2', '0', '112.8', '16.1'], 'Blaine Gabbert': ['\xa032. Blaine Gabbert', 'SF', '6', '91', '160', '925', '5', '6', '40', '173', '2', '95.6', '15.9'], 'Brian Hoyer': ['\x ...

# %%
players = {}

for link in soup.find_all(href=re.compile('/stats/players')):
    name = link.text
    if name != "players":
        row = link.findParent().findParent()
        players[name] = [td.text for td in row.find_all('td')]
print(players)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-9-b66df7b974e7> in <module>()
#       1 players = {}
#       2
# ----> 3 for link in soup.find_all(href=re.compile('/stats/players')):
#       4     name = link.text
#       5     if name != "players":
#
# NameError: name 'soup' is not defined
